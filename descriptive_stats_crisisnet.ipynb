# %% [markdown]
# # Getting Descriptive Statistics
#
# CrisisNET provides a simple, powerful resource for accessing crisis relevant data. Below is a short introduction to pulling down data from CrisisNET and completing some simple data wrangling tasks — setting you up to start pulling and using data on your own.
#
# The example below uses Python 3.3 and was written in iPython notebook. The notebook is avaliable on Nbviewer.

# %% [markdown]
# ### Import required modules

# %%
import requests as re
from mpl_toolkits.basemap import Basemap
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Set pandas to display a maximum of 30 columns

# %%
pd.set_option('display.max_columns', 30)

# %% [markdown]
# ### Create and make an api request to CrisisNET

# %%
api_key = '532d8dc4ed3329652f114b73'
headers = {'Authorization': 'Bearer ' + api_key}
url = 'http://api.crisis.net/item?limit=200'
r = re.get(url, headers=headers)
request_df = pd.DataFrame(r.json())

# %% [markdown]
# ### Clean up the dataframe

# %%
# Create a dataframe from the request's data
df = request_df['data'].apply(pd.Series)

# Set the row index of the dataframe to be the time the report was updated
df["updatedAt"] = pd.to_datetime(df["updatedAt"])
df.index = df['updatedAt']

# Expand the geo column into a full dataframe
geo_df = df['geo'].apply(pd.Series)

# Expand the address components column into it's own dataframe
geo_admin_df = geo_df['addressComponents'].apply(pd.Series)

# Join the two geo dataframes to the primary dataframe
df = pd.concat([df[:], geo_admin_df[:], geo_df[:]], axis=1)

# Extract the latitute and longitude coordinates into their own columns
df['latitude'] = df['coords'].str[1]
df['longitude'] = df['coords'].str[0]

# Expand the tags column into its own dataframe
tags_df = df['tags'].apply(pd.Series)

# Drop everything column after the second column
tags_df = tags_df.ix[:, 0:1]
tags_df.columns = ['tag1', 'tag2']

# Extract the tags
def tag_extractor(x):
    # that, if x is a string,
    if type(x) is float:
        # just returns it untouched
        return x
    # but, if not, convert x to a dict() and return the value from the name key
    elif x:
        x = dict(x)
        return x['name']
    # and leave everything else
    else:
        return
tags_df = tags_df.applymap(tag_extractor)

# Attach the tags to the main dataframe
df = pd.concat([df[:], tags_df[:]], axis=1)

# Expand the language value:key pair
lang_df = df['language'].apply(pd.Series)

# Attach the language code as a column
df['lang'] = lang_df['code']

# print the length and view the first row
print(len(df))
df.head(1)
# Out:
# 200
#                            author  \
# updatedAt
# 2014-06-01 09:51:14.942730    NaN
#
#                                                                   content  \
# updatedAt
# 2014-06-01 09:51:14.942730  Mohammed Yehya al-Houndi killed by Shooting.
#
#                            contentEnglish                   createdAt  \
# updatedAt
# 2014-06-01 09:51:14.942730            NaN  2014-05-28T20:19:51.945796
#
#                            entities  \
# updatedAt
# 2014-06-01 09:51:14.942730      NaN
#
#                                                                       fromURL  \
# updatedAt
# 2014-06-01 09:51:14.942730  http://www.vdc-sy.info/index.php/en/details/ma...
#
#                                                                           geo  \
# updatedAt
# 2014-06-01 09:51:14.942730  {'addressComponents': {'adminArea1': 'Syria', ...
#
#                                                 id image language license  \
# updatedAt
# 2014-06-01 09:51:14.942730  S4aCYMNeRM27iFuKi_mJPw   NaN      NaN      cc
#
#                              lifespan          publishedAt remoteID  \
# updatedAt
# 2014-06-01 09:51:14.942730  temporary  2014-09-16T00:00:00   111181
#
#                                source  \
# updatedAt
# 2014-06-01 09:51:14.942730  vdc_syria
#
#                                                              summary  \
# updatedAt
# 2014-06-01 09:51:14.942730  Adult - Male Civilian killed by Shooting
#
#                                                                          tags  \
# updatedAt
# 2014-06-01 09:51:14.942730  [{'name': 'conflict', 'confidence': 1}, {'name...
#
#                                             updatedAt video adminArea1  \
# updatedAt
# 2014-06-01 09:51:14.942730 2014-06-01 09:51:14.942730   NaN      Syria
#
#                            adminArea3 adminArea5 formattedAddress  \
# updatedAt
# 2014-06-01 09:51:14.942730      Daraa        NaN              NaN
#
#                            neighborhood streetAddress  \
# updatedAt
# 2014-06-01 09:51:14.942730     Sanamain           NaN
#
#                                                             addressComponents  \
# updatedAt
# 2014-06-01 09:51:14.942730  {'adminArea1': 'Syria', 'adminArea3': 'Daraa',...
#
#                            coords locationIdentifiers  latitude  longitude
# updatedAt
# 2014-06-01 09:51:14.942730    NaN                 NaN       NaN        NaN ...
#
# [1 rows x 33 columns]

# %% [markdown]
# ### Number of observations per source

# %%
df['source'].value_counts().fillna(0).plot(kind='bar')

# %% [markdown]
# ### Number of observations per language

# %%
df['lang'].value_counts().fillna(0).plot(kind='bar')

# %% [markdown]
# ### Number of observations per country

# %%
df['adminArea1'].value_counts().fillna(0).plot(kind='bar')

# %% [markdown]
# ### View number of times a tag is appears

# %%
tags = pd.DataFrame([df['tag1'], df['tag2']])
tag_counts = tags.stack().value_counts()
tag_counts
# Out:
# armed-conflict    30
# conflict          28
# military           3
# death              3
# air-combat         3
# human-rights       2
# Votes              2
# disaster           2
# criminal           2
# fire               2
# government         2
# She                1
# rebels             1
# arrest             1
# dtype: int64

# %% [markdown]
# ### Plot number of times a tag is appears

# %%
tags.stack().value_counts().plot(kind='bar')

# %% [markdown]
# ### View the source of observation by source

# %%
pd.crosstab(df['adminArea1'], df['source'], rownames=['SOURCE:'], colnames=['LOCATION:'])
# Out:
# LOCATION:         facebook  twitter  vdc_syria  youtube
# SOURCE:
# Egypt                    0        1          0        0
# General-conflict         0        5          0        0
# Libya                    0        8          0        0
# Syria                  169        0          2        9
# Thailand                 6        0          0        0
#
# [5 rows x 4 columns]

# %% [markdown]
# ### View the language of observations by location

# %%
pd.crosstab(df['adminArea1'], df['lang'], rownames=['LOCATION:'], colnames=['LANGUAGE:'])
# Out:
# LANGUAGE:         ar  en  es  nl  pt  th  vi
# LOCATION:
# Egypt              1   0   0   0   0   0   0
# General-conflict   0   4   0   0   0   0   1
# Libya              4   4   0   0   0   0   0
# Syria             86  41   1   1   3   0   0
# Thailand           0   3   0   0   0   3   0
#
# [5 rows x 7 columns]

# %% [markdown]
# ### View the header and footer of the dataframe

# %%
df.head()
# Out:
#                            author  \
# updatedAt
# 2014-06-01 09:51:14.942730    NaN
# 2014-06-01 09:53:11.429487    NaN
# 2014-06-04 02:36:55.047509    NaN
# 2014-06-04 02:30:14.558210    NaN
# 2014-06-04 02:34:40.901612    NaN
#
#                                                                       content  \
# updatedAt
# 2014-06-01 09:51:14.942730      Mohammed Yehya al-Houndi killed by Shooting.
# 2014-06-01 09:53:11.429487      Mohammed Yehya al-Houndi killed by Shooting.
# 2014-06-04 02:36:55.047509  قناة السوري الحر الفضائية ( صلاة الفجر ) مكة ا...
# 2014-06-04 02:30:14.558210  مجموعة البحث الموسيقي - حسين مروّة\n\nمن المست...
# 2014-06-04 02:34:40.901612  عاهدناكم يا شعب سورية على النصر\n#الجيش_العربي...
#
#                                                                contentEnglish  \
# updatedAt
# 2014-06-01 09:51:14.942730                                                NaN
# 2014-06-01 09:53:11.429487                                                NaN
# 2014-06-04 02:36:55.047509  Free Syrian satellite channel (dawn prayers) M...
# 2014-06-04 02:30:14.558210  Find music group - Marwa Hussein\n\nOf the swa...
# 2014-06-04 02:34:40.901612  Aahidnakm O people of Syria to victory\nArmy _...
#
#                                              createdAt entities  \
# updatedAt
# 2014-06-01 09:51:14.942730  2014-05-28T20:19:51.945796      NaN
# 2014-06-01 09:53:11.429487  2014-05-28T04:20:13.815495      NaN
# 2014-06-04 02:36:55.047509  2014-06-04T02:36:45.356415  [Syria]
# 2014-06-04 02:30:14.558210  2014-06-04T02:30:04.295555  [Syria]
# 2014-06-04 02:34:40.901612  2014-06-04T02:34:31.039971  [Syria]
#
#                                                                       fromURL  \
# updatedAt
# 2014-06-01 09:51:14.942730  http://www.vdc-sy.info/index.php/en/details/ma...
# 2014-06-01 09:53:11.429487  http://www.vdc-sy.info/index.php/en/details/ma...
# 2014-06-04 02:36:55.047509  http://facebook.com/422696344520369_5240711310...
# 2014-06-04 02:30:14.558210                http://facebook.com/261252337411762
# 2014-06-04 02:34:40.901612                http://facebook.com/727851910594949
#
#                                                                           geo  \
# updatedAt
# 2014-06-01 09:51:14.942730  {'addressComponents': {'adminArea1': 'Syria', ...
# 2014-06-01 09:53:11.429487  {'addressComponents': {'adminArea1': 'Syria', ...
# 2014-06-04 02:36:55.047509  {'coords': [38.473472595214844, 35.03312683105...
# 2014-06-04 02:30:14.558210  {'coords': [38.473472595214844, 35.03312683105...
# 2014-06-04 02:34:40.901612  {'coords': [38.473472595214844, 35.03312683105...
#
#                                                 id  \
# updatedAt
# 2014-06-01 09:51:14.942730  S4aCYMNeRM27iFuKi_mJPw
# 2014-06-01 09:53:11.429487  JY3h2j-_RWaGSoBdD6Ey0w
# 2014-06-04 02:36:55.047509  InCnRUdbQ36Cf1cWKUqzNQ
# 2014-06-04 02:30:14.558210  5C9rzBWsROCxCvbLnygeBQ
# 2014-06-04 02:34:40.901612  r2ZLDpQSS-SLMxZfHmHHAQ
#
#                                                                         image  \
# updatedAt
# 2014-06-01 09:51:14.942730                                                NaN
# 2014-06-01 09:53:11.429487                                                NaN
# 2014-06-04 02:36:55.047509  https://fbexternal-a.akamaihd.net/safe_image.p...
# 2014-06-04 02:30:14.558210  https://fbcdn-vthumb-a.akamaihd.net/hvthumb-ak...
# 2014-06-04 02:34:40.901612  https://fbcdn-photos-a-a.akamaihd.net/hphotos-...
#
#                                                                      language  \
# updatedAt
# 2014-06-01 09:51:14.942730                                                NaN
# 2014-06-01 09:53:11.429487                                                NaN
# 2014-06-04 02:36:55.047509  {'nativeName': 'العربية', 'code': 'ar', 'name'...
# 2014-06-04 02:30:14.558210  {'nativeName': 'العربية', 'code': 'ar', 'name'...
# 2014-06-04 02:34:40.901612  {'nativeName': 'العربية', 'code': 'ar', 'name'...
#
#                              license   lifespan                publishedAt  \
# updatedAt
# 2014-06-01 09:51:14.942730        cc  temporary        2014-09-16T00:00:00
# 2014-06-01 09:53:11.429487        cc  temporary        2014-09-16T00:00:00
# 2014-06-04 02:36:55.047509  facebook  temporary  2014-06-04T02:32:35+00:00
# 2014-06-04 02:30:14.558210  facebook  temporary  2014-06-04T02:30:25+00:00
# 2014-06-04 02:34:40.901612  facebook  temporary  2014-06-04T02:30:00+00:00
#
#                                                    remoteID     source  \
# updatedAt
# 2014-06-01 09:51:14.942730                           111181  vdc_syria
# 2014-06-01 09:53:11.429487                           111181  vdc_syria
# 2014-06-04 02:36:55.047509  422696344520369_524071131049556   facebook
# 2014-06-04 02:30:14.558210                  261252337411762   facebook
# 2014-06-04 02:34:40.901612                  727851910594949   facebook
#
#                                                                       summary  \
# updatedAt
# 2014-06-01 09:51:14.942730           Adult - Male Civilian killed by Shooting
# 2014-06-01 09:53:11.429487           Adult - Male Civilian killed by Shooting
# 2014-06-04 02:36:55.047509  قناة السوري الحر الفضائية ( صلاة الفجر ) مكة ا...
# 2014-06-04 02:30:14.558210  مجموعة البحث الموسيقي - حسين مروّة\n\nمن المست...
# 2014-06-04 02:34:40.901612  عاهدناكم يا شعب سورية على النصر\n#الجيش_العربي...
#
#                                                                          tags  \
# updatedAt
# 2014-06-01 09:51:14.942730  [{'name': 'conflict', 'confidence': 1}, {'name...
# 2014-06-01 09:53:11.429487  [{'name': 'conflict', 'confidence': 1}, {'name...
# 2014-06-04 02:36:55.047509                                                NaN
# 2014-06-04 02:30:14.558210                                                NaN
# 2014-06-04 02:34:40.901612                                                NaN
#
#                                             updatedAt  \
# updatedAt
# 2014-06-01 09:51:14.942730 2014-06-01 09:51:14.942730
# 2014-06-01 09:53:11.429487 2014-06-01 09:53:11.429487
# 2014-06-04 02:36:55.047509 2014-06-04 02:36:55.047509
# 2014-06-04 02:30:14.558210 2014-06-04 02:30:14.558210
# 2014-06-04 02:34:40.901612 2014-06-04 02:34:40.901612
#
#                                                                         video  \
# updatedAt
# 2014-06-01 09:51:14.942730                                                NaN
# 2014-06-01 09:53:11.429487                                                NaN
# 2014-06-04 02:36:55.047509                                                NaN
# 2014-06-04 02:30:14.558210  https://fbcdn-video-a.akamaihd.net/hvideo-ak-x...
# 2014-06-04 02:34:40.901612                                                NaN
#
#                            adminArea1 adminArea3 adminArea5 formattedAddress  \
# updatedAt
# 2014-06-01 09:51:14.942730      Syria      Daraa        NaN              NaN
# 2014-06-01 09:53:11.429487      Syria      Daraa        NaN              NaN
# 2014-06-04 02:36:55.047509      Syria        NaN        NaN            Syria
# 2014-06-04 02:30:14.558210      Syria        NaN        NaN            Syria
# 2014-06-04 02:34:40.901612      Syria        NaN        NaN            Syria
#
#                            neighborhood streetAddress  \
# updatedAt
# 2014-06-01 09:51:14.942730     Sanamain           NaN
# 2014-06-01 09:53:11.429487     Sanamain           NaN
# 2014-06-04 02:36:55.047509          NaN           NaN
# 2014-06-04 02:30:14.558210          NaN           NaN
# 2014-06-04 02:34:40.901612          NaN           NaN
#
#                                                             addressComponents  \
# updatedAt
# 2014-06-01 09:51:14.942730  {'adminArea1': 'Syria', 'adminArea3': 'Daraa',...
# 2014-06-01 09:53:11.429487  {'adminArea1': 'Syria', 'adminArea3': 'Daraa',...
# 2014-06-04 02:36:55.047509  {'formattedAddress': 'Syria', 'adminArea1': 'S...
# 2014-06-04 02:30:14.558210  {'formattedAddress': 'Syria', 'adminArea1': 'S...
# 2014-06-04 02:34:40.901612  {'formattedAddress': 'Syria', 'adminArea1': 'S...
#
#                                                              coords  \
# updatedAt
# 2014-06-01 09:51:14.942730                                      NaN
# 2014-06-01 09:53:11.429487                                      NaN
# 2014-06-04 02:36:55.047509  [38.473472595214844, 35.03312683105469]
# 2014-06-04 02:30:14.558210  [38.473472595214844, 35.03312683105469]
# 2014-06-04 02:34:40.901612  [38.473472595214844, 35.03312683105469]
#
#                                                    locationIdentifiers  \
# updatedAt
# 2014-06-01 09:51:14.942730                                         NaN
# 2014-06-01 09:53:11.429487                                         NaN
# 2014-06-04 02:36:55.047509             {'authorLocationName': 'تركيا'}
# 2014-06-04 02:30:14.558210                                         NaN
# 2014-06-04 02:34:40.901612  {'authorLocationName': ' Damascus, Syria'}
#
#                              latitude  longitude
# updatedAt
# 2014-06-01 09:51:14.942730        NaN        NaN ...
# 2014-06-01 09:53:11.429487        NaN        NaN ...
# 2014-06-04 02:36:55.047509  35.033127  38.473473 ...
# 2014-06-04 02:30:14.558210  35.033127  38.473473 ...
# 2014-06-04 02:34:40.901612  35.033127  38.473473 ...
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#                            author  \
# updatedAt
# 2014-06-04 01:33:51.140934    NaN
# 2014-06-04 01:34:56.196292    NaN
# 2014-06-04 01:34:41.729906    NaN
# 2014-06-04 00:40:31.436039    NaN
# 2014-06-04 02:38:09.314566    NaN
#
#                                                                       content  \
# updatedAt
# 2014-06-04 01:33:51.140934  يرفع الان آذان الفجر بتوقيت دمشق المحررة قريبا...
# 2014-06-04 01:34:56.196292  Governor of Homs: More than 644 000 in Homs Vo...
# 2014-06-04 01:34:41.729906  "The will of the Syrian people through voting ...
# 2014-06-04 00:40:31.436039  abo jad tours \n\nتنويه : فيما يخص إشاعة الغاء...
# 2014-06-04 02:38:09.314566  حين سئل الشاعر أحمد مطر ما هي نصائحك إلى القرا...
#
#                                                                contentEnglish  \
# updatedAt
# 2014-06-04 01:33:51.140934  Raises far ears Dawn Time Damascus liberated s...
# 2014-06-04 01:34:56.196292                                                NaN
# 2014-06-04 01:34:41.729906                                                NaN
# 2014-06-04 00:40:31.436039  abo jad tours\n\nDisclaimer: Regarding rumor c...
# 2014-06-04 02:38:09.314566                                                NaN
#
#                                              createdAt entities  \
# updatedAt
# 2014-06-04 01:33:51.140934  2014-06-04T01:33:41.406417  [Syria]
# 2014-06-04 01:34:56.196292  2014-06-04T01:34:41.689972  [Syria]
# 2014-06-04 01:34:41.729906  2014-06-04T01:34:41.729895      NaN
# 2014-06-04 00:40:31.436039  2014-06-04T00:40:21.687859  [Syria]
# 2014-06-04 02:38:09.314566  2014-06-04T02:38:09.314554      NaN
#
#                                                                       fromURL  \
# updatedAt
# 2014-06-04 01:33:51.140934               http://facebook.com/1506835209537961
# 2014-06-04 01:34:56.196292  http://facebook.com/298382103530912_6851488448...
# 2014-06-04 01:34:41.729906                http://facebook.com/685148648187587
# 2014-06-04 00:40:31.436039  http://facebook.com/369949626434443_6228387244...
# 2014-06-04 02:38:09.314566                http://facebook.com/670941639653421
#
#                                                                           geo  \
# updatedAt
# 2014-06-04 01:33:51.140934  {'coords': [38.473472595214844, 35.03312683105...
# 2014-06-04 01:34:56.196292  {'coords': [38.473472595214844, 35.03312683105...
# 2014-06-04 01:34:41.729906     {'addressComponents': {'adminArea1': 'Syria'}}
# 2014-06-04 00:40:31.436039  {'coords': [38.473472595214844, 35.03312683105...
# 2014-06-04 02:38:09.314566  {'locationIdentifiers': {'authorLocationName':...
#
#                                                 id  \
# updatedAt
# 2014-06-04 01:33:51.140934  K4YA2Da9Q5eJUyPACC5Bgg
# 2014-06-04 01:34:56.196292  HFpDxoLCSou7ODjj9BGAYw
# 2014-06-04 01:34:41.729906  hCGXMjzTRsO1DKn-pdV9PQ
# 2014-06-04 00:40:31.436039  ywNp1DXjQSuoSt3U-I5JJA
# 2014-06-04 02:38:09.314566  pGgUaeOxSbiel3kmT-noPA
#
#                                                                         image  \
# updatedAt
# 2014-06-04 01:33:51.140934  https://fbcdn-photos-h-a.akamaihd.net/hphotos-...
# 2014-06-04 01:34:56.196292                                                NaN
# 2014-06-04 01:34:41.729906  https://fbcdn-photos-h-a.akamaihd.net/hphotos-...
# 2014-06-04 00:40:31.436039                                                NaN
# 2014-06-04 02:38:09.314566  https://fbcdn-photos-g-a.akamaihd.net/hphotos-...
#
#                                                                      language  \
# updatedAt
# 2014-06-04 01:33:51.140934  {'nativeName': 'العربية', 'code': 'ar', 'name'...
# 2014-06-04 01:34:56.196292  {'nativeName': 'English', 'code': 'en', 'name'...
# 2014-06-04 01:34:41.729906                                                NaN
# 2014-06-04 00:40:31.436039  {'nativeName': 'العربية', 'code': 'ar', 'name'...
# 2014-06-04 02:38:09.314566                                                NaN
#
#                              license   lifespan                publishedAt  \
# updatedAt
# 2014-06-04 01:33:51.140934  facebook  temporary  2014-06-04T00:38:14+00:00
# 2014-06-04 01:34:56.196292  facebook  temporary  2014-06-04T00:38:08+00:00
# 2014-06-04 01:34:41.729906  facebook  temporary  2014-06-04T00:37:23+00:00
# 2014-06-04 00:40:31.436039  facebook  temporary  2014-06-04T00:36:52+00:00
# 2014-06-04 02:38:09.314566  facebook  temporary  2014-06-04T00:35:46+00:00
#
#                                                    remoteID    source  \
# updatedAt
# 2014-06-04 01:33:51.140934                 1506835209537961  facebook
# 2014-06-04 01:34:56.196292  298382103530912_685148844854234  facebook
# 2014-06-04 01:34:41.729906                  685148648187587  facebook
# 2014-06-04 00:40:31.436039  369949626434443_622838724478864  facebook
# 2014-06-04 02:38:09.314566                  670941639653421  facebook
#
#                                                                       summary  \
# updatedAt
# 2014-06-04 01:33:51.140934  يرفع الان آذان الفجر بتوقيت دمشق المحررة قريبا...
# 2014-06-04 01:34:56.196292  Governor of Homs: More than 644 000 in Homs Vo...
# 2014-06-04 01:34:41.729906  "The will of the Syrian people through voting ...
# 2014-06-04 00:40:31.436039  abo jad tours \n\nتنويه : فيما يخص إشاعة الغاء...
# 2014-06-04 02:38:09.314566  حين سئل الشاعر أحمد مطر ما هي نصائحك إلى القرا...
#
#                                                                          tags  \
# updatedAt
# 2014-06-04 01:33:51.140934  [{'name': 'armed-conflict', 'confidence': 1}, ...
# 2014-06-04 01:34:56.196292                                                NaN
# 2014-06-04 01:34:41.729906                                                NaN
# 2014-06-04 00:40:31.436039  [{'name': 'fire', 'confidence': 1}, {'name': '...
# 2014-06-04 02:38:09.314566                                                NaN
#
#                                             updatedAt video adminArea1  \
# updatedAt
# 2014-06-04 01:33:51.140934 2014-06-04 01:33:51.140934   NaN      Syria
# 2014-06-04 01:34:56.196292 2014-06-04 01:34:56.196292   NaN      Syria
# 2014-06-04 01:34:41.729906 2014-06-04 01:34:41.729906   NaN      Syria
# 2014-06-04 00:40:31.436039 2014-06-04 00:40:31.436039   NaN      Syria
# 2014-06-04 02:38:09.314566 2014-06-04 02:38:09.314566   NaN      Syria
#
#                            adminArea3 adminArea5 formattedAddress  \
# updatedAt
# 2014-06-04 01:33:51.140934        NaN        NaN            Syria
# 2014-06-04 01:34:56.196292        NaN        NaN            Syria
# 2014-06-04 01:34:41.729906        NaN        NaN              NaN
# 2014-06-04 00:40:31.436039        NaN        NaN            Syria
# 2014-06-04 02:38:09.314566        NaN        NaN              NaN
#
#                            neighborhood streetAddress  \
# updatedAt
# 2014-06-04 01:33:51.140934          NaN           NaN
# 2014-06-04 01:34:56.196292          NaN           NaN
# 2014-06-04 01:34:41.729906          NaN           NaN
# 2014-06-04 00:40:31.436039          NaN           NaN
# 2014-06-04 02:38:09.314566          NaN           NaN
#
#                                                             addressComponents  \
# updatedAt
# 2014-06-04 01:33:51.140934  {'formattedAddress': 'Syria', 'adminArea1': 'S...
# 2014-06-04 01:34:56.196292  {'formattedAddress': 'Syria', 'adminArea1': 'S...
# 2014-06-04 01:34:41.729906                            {'adminArea1': 'Syria'}
# 2014-06-04 00:40:31.436039  {'formattedAddress': 'Syria', 'adminArea1': 'S...
# 2014-06-04 02:38:09.314566                            {'adminArea1': 'Syria'}
#
#                                                              coords  \
# updatedAt
# 2014-06-04 01:33:51.140934  [38.473472595214844, 35.03312683105469]
# 2014-06-04 01:34:56.196292  [38.473472595214844, 35.03312683105469]
# 2014-06-04 01:34:41.729906                                      NaN
# 2014-06-04 00:40:31.436039  [38.473472595214844, 35.03312683105469]
# 2014-06-04 02:38:09.314566                                      NaN
#
#                                                           locationIdentifiers  \
# updatedAt
# 2014-06-04 01:33:51.140934  {'authorLocationName': 'Damascus, Syria Damasc...
# 2014-06-04 01:34:56.196292                                                NaN
# 2014-06-04 01:34:41.729906                                                NaN
# 2014-06-04 00:40:31.436039         {'authorLocationName': 'مصر Cairo, Egypt'}
# 2014-06-04 02:38:09.314566             {'authorLocationName': ' Duma, Syria'}
#
#                              latitude  longitude
# updatedAt
# 2014-06-04 01:33:51.140934  35.033127  38.473473 ...
# 2014-06-04 01:34:56.196292  35.033127  38.473473 ...
# 2014-06-04 01:34:41.729906        NaN        NaN ...
# 2014-06-04 00:40:31.436039  35.033127  38.473473 ...
# 2014-06-04 02:38:09.314566        NaN        NaN ...
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Plot the dates of the observations

# %%
df['createdAt'] = pd.to_datetime(df['createdAt'])
d2 = df.set_index('createdAt').resample('D', 'count')
d2.drop_duplicates(take_last=False, inplace=True)
d2 = d2.unstack().rename(columns={'content': 'daily_total'})
d2 = d2['daily_total']
d2.plot(kind='bar')

# %% [markdown]
# ### View number of missing observations per variable

# %%
df.apply(lambda x: x.isnull().value_counts()).T.plot(kind='bar', stacked=True)

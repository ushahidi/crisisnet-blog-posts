# %%
# Import modules
import pandas as pd
import requests
import numpy as np

# Set ipython's max row display
pd.set_option('display.max_row', 1000)

# Set iPython's max column width to 50
pd.set_option('display.max_columns', 50)

# %%
# Insert your CrisisNET API key
api_key = '532d8dc4ed3329652f114b73'

# Insert your CrisisNET request API
api_url = 'http://api.crisis.net/item?sources=ushahidi_v2&authorName=lern&text=ebola'

# Create the request header
headers = {'Authorization': 'Bearer ' + api_key}

# Define how many data points you want
total = 10000

# Create a dataframe where the request data will go
df = pd.DataFrame()

# %%
# Define a function called get data,
def get_data(offset=0, limit=100, df=None):
    # create a variable called url, which has the request info,
    url = api_url + '&offset=' + str(offset) + '&limit=' + str(limit)
    # a variable called r, with the request data,
    r = requests.get(url, headers=headers)
    # convert the request data into a dataframe,
    x = pd.DataFrame(r.json())
    # expand the dataframe
    x = x['data'].apply(pd.Series)
    # add the dataframe's rows to the main dataframe, df, we defined outside the function
    df = df.append(x, ignore_index=True)

    # then, if the total is larger than the request limit plus offset,
    if total > offset + limit:
        # run the function another time
        return get_data(offset + limit, limit, df)
    # but if not, end the function
    return df

# %%
# Run the function
df = get_data(df=df)

# %%
# Check for duplicate data points
df['id'].duplicated().value_counts()

# Drop all duplicate data points
df = df.dropna(how='all')

# Check the number of data points retrieved
len(df)
# Out:
# 20

# %%
# Define a function that,
def flatten_df(df):
    df["updatedAt"] = pd.to_datetime(df["updatedAt"])
    # sets it as the dataframe's index,
    df.index = df['updatedAt']
    # expands the df.geo object,
    geo_df = df['geo'].apply(pd.Series)
    # expands the admin zones,
    geo_admin_df = geo_df['addressComponents'].apply(pd.Series)
    # merges the admin zones back into the dataframe,
    df = pd.concat([df[:], geo_admin_df[:], geo_df[:]], axis=1)
    # seperates the lat and long objects,
    # df['latitude'], df['longitude'] = df['coords'].str[1], df['coords'].str[0]
    # expands df.tags,
    tags_df = df['tags'].apply(pd.Series)
    # defines a function called tag_extractor,
    def tag_extractor(x):
        # that, if x is a string,
        if type(x) is float:
            # just returns it untouched
            return x
        # but, if not, convert x to a dict() and return the value
        elif x:
            x = dict(x)
            return x['name']
        # and leave everything else
        else:
            return
    # executes tag_extractor on the tags dataframe,
    tags_df = tags_df.applymap(tag_extractor)
    # renames all the tag columns,
    tags_df = tags_df.rename(columns = lambda x : 'tag_' + str(x))
    # merges everything back together,
    df = pd.concat([df[:], tags_df[:]], axis=1)
    # expands df.language,
    # lang_df = df['language'].apply(pd.Series)
    # takes the language code,
    # df['lang'] = lang_df['code']
    # and finally returns the primary dataframe
    return df

# %%
df
# Out:
#                                   author  \
# 0   {'name': 'LERN', 'remoteID': '0001'}
# 1   {'name': 'LERN', 'remoteID': '0001'}
# 2   {'name': 'LERN', 'remoteID': '0001'}
# 3   {'name': 'LERN', 'remoteID': '0001'}
# 4   {'name': 'LERN', 'remoteID': '0001'}
# 5   {'name': 'LERN', 'remoteID': '0001'}
# 6   {'name': 'LERN', 'remoteID': '0001'}
# 7   {'name': 'LERN', 'remoteID': '0001'}
# 8   {'name': 'LERN', 'remoteID': '0001'}
# 9   {'name': 'LERN', 'remoteID': '0001'}
# 10  {'name': 'LERN', 'remoteID': '0001'}
# 11  {'name': 'LERN', 'remoteID': '0001'}
# 12  {'name': 'LERN', 'remoteID': '0001'}
# 13  {'name': 'LERN', 'remoteID': '0001'}
# 14  {'name': 'LERN', 'remoteID': '0001'}
# 15  {'name': 'LERN', 'remoteID': '0001'}
# 16  {'name': 'LERN', 'remoteID': '0001'}
# 17  {'name': 'LERN', 'remoteID': '0001'}
# 18  {'name': 'LERN', 'remoteID': '0001'}
# 19  {'name': 'LERN', 'remoteID': '0001'}
#
#                                               content  \
# 0   On August 7, 2014 in Kolba City, Kolahun Distr...
# 1   On August 6, 2014 it was reported from Zota Di...
# 2   On August 4, 2014 it was reported in Gbarnga C...
# 3   On August 4, 2014 at the Kolahun Referral Hosp...
# 4   An eye witness has reported that Community dwe...
# 5   On July 29, 2014 the border between Guinea and...
# 6   On July 28, 2014 it was reported from Zota Dis...
# 7   July 28,2014 in Popalahun Town, Kolahun Distri...
# 8   On July 23, 2014 at the Phebe Hospital in Bong...
# 9   On July 17, 2014 at the G.W. Harlay hospital i...
# 10  On July 16 2014, the Health Minister, DR. Gwen...
# 11  On July 10, 2014 in Bolonquidu Town, Quardu Gb...
# 12  An 11 years old girl by the name of Abigil die...
# 13  Reports coming in from Fuahmah District, Bong ...
# 14  IT WAS REPORTED THAT THREE SUSPECTED EBOLA CAS...
# 15  June 11, 2014. Credible reports coming from Fo...
# 16  Reports coming in from Lofa county say Ebola v...
# 17  Sarkonedu Town,Quardu Gboni District, 10/4/201...
# 18  On April 2, 2014, UNMIL Radio report at 1:00pm...
# 19  As the Government of Liberia and some of its i...
#
#                      createdAt  \
# 0   2014-08-10T17:10:48.724446
# 1   2014-08-10T17:10:48.775635
# 2   2014-08-10T17:10:48.811047
# 3   2014-08-10T17:10:48.839569
# 4   2014-08-10T17:10:48.882630
# 5   2014-08-10T17:10:48.926575
# 6   2014-08-10T17:10:48.983310
# 7   2014-08-10T17:10:49.039756
# 8   2014-08-10T17:10:49.083935
# 9   2014-08-10T17:10:49.118505
# 10  2014-08-10T17:10:49.169038
# 11  2014-08-10T17:10:49.259590
# 12  2014-08-10T17:10:49.280494
# 13  2014-08-10T17:10:49.370946
# 14  2014-08-10T17:10:49.511531
# 15  2014-08-10T17:10:49.670379
# 16  2014-08-10T17:10:49.686310
# 17  2014-08-07T03:42:54.683843
# 18  2014-08-07T03:42:54.823684
# 19  2014-08-07T03:42:54.861205
#
#                                                   geo                      id  \
# 0   {'addressComponents': {'formattedAddress': 'Ko...  MqnyZBARR52RyYsxmonR1g
# 1   {'addressComponents': {'formattedAddress': 'Zo...  x9jl7iVfT7a68qnxweB1zw
# 2   {'addressComponents': {'formattedAddress': 'Gb...  B_gzWioCQG-sVLYJ854TEA
# 3   {'addressComponents': {'formattedAddress': 'Ko...  o5AUmd9sT1CpubqTAJwLWg
# 4   {'addressComponents': {'formattedAddress': 'Ol...  TCew0oHCQjWaPFS9bBeNsQ
# 5   {'addressComponents': {'formattedAddress': 'Zo...  EMbnNL5TT4mN33O2XLV8mA
# 6   {'addressComponents': {'formattedAddress': 'Zo...  UOu4hozTTc2cWfW0fRGFyw
# 7   {'addressComponents': {'formattedAddress': 'Ko...  GZmJfvp7S5-ukUGsRdbmlQ
# 8   {'addressComponents': {'formattedAddress': 'Gb...  eHtjWIZkRCygeM6FYVtliQ
# 9   {'addressComponents': {'formattedAddress': 'Sa...  nEgHVC1-QPGfmvq2lbEb-Q
# 10  {'addressComponents': {'formattedAddress': 'Vo...  HnkhCrgYTuqQyP6gKO3DPw
# 11  {'addressComponents': {'formattedAddress': 'Qu...  wtzkfXXLTtCSrMBGQAzsoA
# 12  {'addressComponents': {'formattedAddress': 'Ma...  V2O96OJSQziVtgCMUosg1g
# 13  {'addressComponents': {'formattedAddress': 'Fu...  spaJY-cpRx-Jjh2F8rC23A
# 14  {'addressComponents': {'formattedAddress': 'ZO...  pHUvm900RA6rOPfLtBoang
# 15  {'addressComponents': {'formattedAddress': 'Fo...  YhShvkOtTOCdq9QmsH7tww
# 16  {'addressComponents': {'formattedAddress': 'Fo...  EiLNWbIxSreiFqWbgHIHYw
# 17  {'addressComponents': {'formattedAddress': 'Sa...  iKkPIxAWSjessgV1yK_uOA
# 18  {'addressComponents': {'formattedAddress': 'Ga...  J6F86q_VSV2tAeEuhm2duQ
# 19  {'addressComponents': {'formattedAddress': 'Mo...  lPO9jGJmSniTBCU7EQN7KQ
#
#     license   lifespan          publishedAt    remoteID       source  \
# 0   unknown  temporary  2014-08-07T09:06:00  0001-17672  ushahidi_v2
# 1   unknown  temporary  2014-08-06T01:47:00  0001-17668  ushahidi_v2
# 2   unknown  temporary  2014-08-04T01:59:00  0001-17666  ushahidi_v2
# 3   unknown  temporary  2014-08-04T01:22:00  0001-17663  ushahidi_v2
# 4   unknown  temporary  2014-07-30T13:22:00  0001-17652  ushahidi_v2
# 5   unknown  temporary  2014-07-29T06:32:00  0001-17657  ushahidi_v2
# 6   unknown  temporary  2014-07-28T10:02:00  0001-17660  ushahidi_v2
# 7   unknown  temporary  2014-07-28T06:55:00  0001-17658  ushahidi_v2
# 8   unknown  temporary  2014-07-23T06:04:00  0001-17659  ushahidi_v2
# 9   unknown  temporary  2014-07-17T05:06:00  0001-17653  ushahidi_v2
# 10  unknown  temporary  2014-07-16T08:27:00  0001-17645  ushahidi_v2
# 11  2014-08-10T17:10:49.259602
# 12  2014-08-10T17:10:49.280512
# 13  2014-08-10T17:10:49.370964
# 14  2014-08-10T17:10:49.511543
# 15  2014-08-10T17:10:49.670397
# 16  2014-08-10T17:10:49.686322
# 17  2014-08-07T03:42:54.683856
# 18  2014-08-07T03:42:54.823695
# 19  2014-08-07T03:42:54.861222

# %%
# Run the function to flatten to dataframe
df = flatten_df(df)

# %%
df.head()
# Out:
#                                                           author  \
# updatedAt
# 2014-08-10 17:10:48.724458  {'name': 'LERN', 'remoteID': '0001'}
# 2014-08-10 17:10:48.775649  {'name': 'LERN', 'remoteID': '0001'}
# 2014-08-10 17:10:48.811059  {'name': 'LERN', 'remoteID': '0001'}
# 2014-08-10 17:10:48.839582  {'name': 'LERN', 'remoteID': '0001'}
# 2014-08-10 17:10:48.882641  {'name': 'LERN', 'remoteID': '0001'}
#
#                                                                       content  \
# updatedAt
# 2014-08-10 17:10:48.724458  On August 7, 2014 in Kolba City, Kolahun Distr...
# 2014-08-10 17:10:48.775649  On August 6, 2014 it was reported from Zota Di...
# 2014-08-10 17:10:48.811059  On August 4, 2014 it was reported in Gbarnga C...
# 2014-08-10 17:10:48.839582  On August 4, 2014 at the Kolahun Referral Hosp...
# 2014-08-10 17:10:48.882641  An eye witness has reported that Community dwe...
#
#                                              createdAt  \
# updatedAt
# 2014-08-10 17:10:48.724458  2014-08-10T17:10:48.724446
# 2014-08-10 17:10:48.775649  2014-08-10T17:10:48.775635
# 2014-08-10 17:10:48.811059  2014-08-10T17:10:48.811047
# 2014-08-10 17:10:48.839582  2014-08-10T17:10:48.839569
# 2014-08-10 17:10:48.882641  2014-08-10T17:10:48.882630
#
#                                                                           geo  \
# updatedAt
# 2014-08-10 17:10:48.724458  {'addressComponents': {'formattedAddress': 'Ko...
# 2014-08-10 17:10:48.775649  {'addressComponents': {'formattedAddress': 'Zo...
# 2014-08-10 17:10:48.811059  {'addressComponents': {'formattedAddress': 'Gb...
# 2014-08-10 17:10:48.839582  {'addressComponents': {'formattedAddress': 'Ko...
# 2014-08-10 17:10:48.882641  {'addressComponents': {'formattedAddress': 'Ol...
#
#                                                 id  license   lifespan  \
# updatedAt
# 2014-08-10 17:10:48.724458  MqnyZBARR52RyYsxmonR1g  unknown  temporary
# 2014-08-10 17:10:48.775649  x9jl7iVfT7a68qnxweB1zw  unknown  temporary
# 2014-08-10 17:10:48.811059  B_gzWioCQG-sVLYJ854TEA  unknown  temporary
# 2014-08-10 17:10:48.839582  o5AUmd9sT1CpubqTAJwLWg  unknown  temporary
# 2014-08-10 17:10:48.882641  TCew0oHCQjWaPFS9bBeNsQ  unknown  temporary
#
#                                     publishedAt    remoteID       source  \
# updatedAt
# 2014-08-10 17:10:48.724458  2014-08-07T09:06:00  0001-17672  ushahidi_v2

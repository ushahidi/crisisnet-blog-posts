# %%
# Import modules
import pandas as pd
import requests
import numpy as np

# Set ipython's max row display
pd.set_option('display.max_row', 1000)

# %%
# Insert your CrisisNET API key
api_key = '532d8dc4ed3329652f114b73'

# Insert your CrisisNET request API
api_url = 'http://api.crisis.net/item/?sources=vdc_syria'

# Create the request header
headers = {'Authorization': 'Bearer ' + api_key}

# Define how many data points you want
total = 10000

# Create a dataframe where the request data will go
df = pd.DataFrame()

# %%
# Define a function called get data,
def get_data(offset=0, limit=100, df=None):
    # create a variable called url, which has the request info,
    url = api_url + '&offset=' + str(offset) + '&limit=' + str(limit)
    # a variable called r, with the request data,
    r = requests.get(url, headers=headers)
    # convert the request data into a dataframe,
    x = pd.DataFrame(r.json())
    # expand the dataframe
    x = x['data'].apply(pd.Series)
    # add the dataframe's rows to the main dataframe, df, we defined outside the function
    df = df.append(x, ignore_index=True)

    # then, if the total is larger than the request limit plus offset,
    if total > offset + limit:
        # run the function another time
        return get_data(offset + limit, limit, df)
    # but if not, end the function
    return df

# %%
# Run the function
df = get_data(df=df)

# %%
# Check the number of data points retrieved
len(df)
# Out:
# 3268

# %%
# Check for duplicate data points
df['id'].duplicated().value_counts()
# Out:
# False    3201
# True       67
# dtype: int64

# %%
# Drop all duplicate data points
df = df.dropna(how='all')

# %%
# View the first 10 data points
df.head()
# Out:
#                                              content contentEnglish  \
# 0      Mohammed Yehya al-Houndi killed by Shooting.             NaN
# 1      Mohammed Yehya al-Houndi killed by Shooting.             NaN
# 2  Hazar Mostafa Gazi al-Aeraj killed by \n\t\t\t...            NaN
# 3  ÙAbo Nader al-Dehraui killed by  . Did not re...            NaN
# 4  Mohammad Omar Hamed al-Khatib killed by  . Mar...            NaN
#
#                     createdAt  \
# 0  2014-05-28T20:19:51.945796
# 1  2014-05-28T04:20:13.815495
# 2  2014-07-14T20:36:44.182603
# 3  2014-06-28T20:39:15.460526
# 4  2014-06-28T20:39:15.055125
#
#                                             entities  \
# 0                                                NaN
# 1                                                NaN
# 2  [\n\t\t\t\t\t\t\t\t\tKaferzita\t\t\t\t\t\t\t\t...
# 3                          [Samra village,  , Syria]
# 4                            [Mouadamiyeh,  , Syria]
#
#                                              fromURL  \
# 0  http://www.vdc-sy.info/index.php/en/details/ma...
# 1  http://www.vdc-sy.info/index.php/en/details/ma...
# 2  http://www.vdc-sy.info/index.php/en/details/ma...
# 3  http://www.vdc-sy.info/index.php/en/details/ma...
# 4  http://www.vdc-sy.info/index.php/en/details/ma...
#
#                                                  geo                      id  \
# 0  {'addressComponents': {'adminArea3': 'Daraa', ...  S4aCYMNeRM27iFuKi_mJPw
# 1  {'addressComponents': {'adminArea3': 'Daraa', ...  JY3h2j-_RWaGSoBdD6Ey0w
# 2  {'addressComponents': {'neighborhood': '
# 					...  7b7nEI-zTJeoCgvj5PUX1g
# 3  {'addressComponents': {'neighborhood': 'Samra ...  Ax-MlUDfTCOCOFjCTFdmzA
# 4  {'addressComponents': {'adminArea1': 'Syria', ...  ygZljAitQuCXrTvbgW2LIw
#
#   image                                           language license   lifespan  \
# 0   NaN                                                NaN      cc  temporary
# 1   NaN                                                NaN      cc  temporary
# 2  Name  {'code': 'en', 'nativeName': 'English', 'name'...      cc  temporary
# 3   NaN  {'code': 'en', 'nativeName': 'English', 'name'...      cc  temporary
# 4   NaN  {'code': 'en', 'nativeName': 'English', 'name'...      cc  temporary
#
#            publishedAt remoteID     source  \
# 0  2014-09-16T00:00:00   111181  vdc_syria
# 1  2014-09-16T00:00:00   111181  vdc_syria
# 2  2014-07-14T00:00:00   128592  vdc_syria
# 3  2014-06-28T00:00:00   127356  vdc_syria
# 4  2014-06-28T00:00:00   127354  vdc_syria
#
#                                              summary  \
# 0           Adult - Male Civilian killed by Shooting
# 1           Adult - Male Civilian killed by Shooting
# 2  \n\t\t\t\t\t\t\t\t\tChild - Female\t\t\t\t\t\t...
# 3                                        killed by
# 4                                        killed by
#
#                                                 tags  \
# 0  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 1  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 2  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 3  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 4  [{'confidence': 1, 'name': 'conflict'}, {'conf...
#
#                     updatedAt video
# 0  2014-06-01T09:51:14.942730   NaN
# 1  2014-06-01T09:53:11.429487   NaN
# 2  2014-07-14T20:37:21.649282   NaN
# 3  2014-06-28T20:39:41.865291   NaN
# 4  2014-06-28T20:39:41.938860   NaN
#
# [5 rows x 18 columns]

# %%
# View the first 10 data points
df.tail()
# Out:
#                                                 content contentEnglish  \
# 3195  Ahmad Khozam  disappeared near Damascus Suburb...            NaN
# 3196  Rokia Mohammad al-Ahmad  disappeared near Dama...            NaN
# 3197  Mohammad Bakour  disappeared near Nabk. Wounde...            NaN
# 3198  Amjad Taha al-Qaddah  disappeared near Dara: S...            NaN
# 3199  Mohammad Mahmoud Mashlah  disappeared near Ale...            NaN
#
#                        createdAt entities  \
# 3195  2014-06-28T20:40:14.246608      NaN
# 3196  2014-06-28T20:40:13.964960      NaN
# 3197  2014-06-14T20:22:02.622251      NaN
# 3198  2014-06-28T20:40:14.517877      NaN
# 3199  2014-06-13T20:22:05.550604      NaN
#
#                                                 fromURL  \
# 3195  http://www.vdc-sy.info/index.php/en/details/mi...
# 3196  http://www.vdc-sy.info/index.php/en/details/mi...
# 3197  http://www.vdc-sy.info/index.php/en/details/mi...
# 3198  http://www.vdc-sy.info/index.php/en/details/mi...
# 3199  http://www.vdc-sy.info/index.php/en/details/mi...
#
#                                                     geo  \
# 3195  {'addressComponents': {'adminArea3': 'Deir Ezz...
# 3196  {'addressComponents': {'adminArea3': 'Deir Ezz...
# 3197  {'addressComponents': {'adminArea3': 'Damascus...
# 3198  {'addressComponents': {'adminArea3': 'Daraa', ...
# 3199  {'addressComponents': {'adminArea3': 'Aleppo',...
#
#                           id image language license   lifespan  \
# 3195  RZSymv4cQZeAmZ2vlUcaNw   NaN      NaN      cc  temporary
# 3196  fFJbj-SgSqGdffrqaw1vMQ   NaN      NaN      cc  temporary
# 3197  3VlQRTbWQTeRA0VqUi2dBg   NaN      NaN      cc  temporary
# 3198  PVYqWTrRQ-WZfCb0oRhOig   NaN      NaN      cc  temporary
# 3199  lXztD78NSPaCSlIN5pSINA   NaN      NaN      cc  temporary
#
#               publishedAt            remoteID     source  \
# 3195  2013-12-14T00:00:00  2286-disappearance  vdc_syria
# 3196  2013-12-14T00:00:00  2285-disappearance  vdc_syria
# 3197  2013-12-06T00:00:00  2208-disappearance  vdc_syria
# 3198  2013-12-06T00:00:00  2183-disappearance  vdc_syria
# 3199  2013-12-03T00:00:00  2160-disappearance  vdc_syria
#
#                                                 summary  \
# 3195  Child - Male  disappeared near Damascus Suburb...
# 3196  Adult - Female  disappeared near Damascus Subu...
# 3197                Child - Male  disappeared near Nabk
# 3198         Adult - Male  disappeared near Dara: Saida
# 3199  Adult - Male  disappeared near Aleppo: Zahraa ...
#
#                                                    tags  \
# 3195  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 3196  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 3197  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 3198  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 3199  [{'confidence': 1, 'name': 'conflict'}, {'conf...
#
#                        updatedAt video
# 3195  2014-06-28T20:40:14.246621   NaN
# 3196  2014-06-28T20:40:13.964972   NaN
# 3197  2014-06-14T20:22:02.622265   NaN
# 3198  2014-06-28T20:40:14.517890   NaN
# 3199  2014-06-13T20:22:05.550617   NaN
#
# [5 rows x 18 columns]

# %%
# Import modules
import pandas as pd
import requests
import numpy as np

# Set ipython's max row display
pd.set_option('display.max_row', 1000)

# %%
# Insert your CrisisNET API key
api_key = '532d8dc4ed3329652f114b73'

# Insert your CrisisNET request API
api_url = 'http://api.crisis.net/item/?sources=noaa_alerts'

# Create the request header
headers = {'Authorization': 'Bearer ' + api_key}

# Define how many data points you want
total = 10000

# Create a dataframe where the request data will go
df = pd.DataFrame()

# %%
# Define a function called get data,
def get_data(offset=0, limit=100, df=None):
    # create a variable called url, which has the request info,
    url = api_url + '&offset=' + str(offset) + '&limit=' + str(limit)
    # a variable called r, with the request data,
    r = requests.get(url, headers=headers)
    # convert the request data into a dataframe,
    x = pd.DataFrame(r.json())
    # expand the dataframe
    x = x['data'].apply(pd.Series)
    # add the dataframe's rows to the main dataframe, df, we defined outside the function
    df = df.append(x, ignore_index=True)

    # then, if the total is larger than the request limit plus offset,
    if total > offset + limit:
        # run the function another time
        return get_data(offset + limit, limit, df)
    # but if not, end the function
    return df

# %%
# Run the function
df = get_data(df=df)

# %%
# Check the number of data points retrieved
len(df)
# Out:
# 440

# %%
# Check for duplicate data points
df['id'].duplicated().value_counts()
# Out:
# False    345
# True      95
# dtype: int64

# %%
# Drop all duplicate data points
df = df.dropna(how='all')

# %%
# View the first 10 data points
df.head()
# Out:
#                                      author  \
# 0  {'remoteID': 'w-nws.webmaster@noaa.gov'}
# 1  {'remoteID': 'w-nws.webmaster@noaa.gov'}
# 2  {'remoteID': 'w-nws.webmaster@noaa.gov'}
# 3  {'remoteID': 'w-nws.webmaster@noaa.gov'}
# 4  {'remoteID': 'w-nws.webmaster@noaa.gov'}
#
#                                              content contentEnglish  \
# 0  ...FROM THE NATIONAL WEATHER SERVICE IN LITTLE...            NaN
# 1  ...STRONG THUNDERSTORMS OVER NIAGARA AND ORLEA...            NaN
# 2  ...SCATTERED AFTERNOON AND EVENING THUNDERSTOR...            NaN
# 3  ...HOT CONDITIONS EXPECTED AGAIN TODAY... ...H...            NaN
# 4  ...HOT CONDITIONS EXPECTED AGAIN TODAY... ...H...            NaN
#
#                     createdAt                                    entities  \
# 0  2014-07-30T16:28:26.392041  [Augusta, Woodruff Co., AR, United States]
# 1  2014-07-30T16:28:26.892951        [Niagara Falls, Niagara, ON, Canada]
# 2  2014-07-30T16:28:27.237735                                          []
# 3  2014-07-30T16:28:26.694482                                          []
# 4  2014-07-30T16:28:27.308871                                          []
#
#                                              fromURL  \
# 0  http://alerts.weather.gov/cap/wwacapget.php?x=...
# 1  http://alerts.weather.gov/cap/wwacapget.php?x=...
# 2  http://alerts.weather.gov/cap/wwacapget.php?x=...
# 3  http://alerts.weather.gov/cap/wwacapget.php?x=...
# 4  http://alerts.weather.gov/cap/wwacapget.php?x=...
#
#                                                  geo                      id  \
# 0  {'coords': [-91.33, 35.1], 'addressComponents'...  DrwZGjCbT0GxDH48fX83mQ
# 1  {'coords': [-79.07, 43.14], 'addressComponents...  PIQKj72mQsW7lrTjK4uYGg
# 2                                                NaN  Qv2Co0KbRf24tBGQW5HG3g
# 3                                                NaN  8Nu6pQw7RJyncihcFN7SXw
# 4                                                NaN  6Lt84bUrRqKe0V174dMoWg
#
#                                             language  license   lifespan  \
# 0  {'nativeName': 'English', 'code': 'en', 'name'...  unknown  temporary
# 1  {'nativeName': 'English', 'code': 'en', 'name'...  unknown  temporary
# 2  {'nativeName': 'English', 'code': 'en', 'name'...  unknown  temporary
# 3  {'nativeName': 'English', 'code': 'en', 'name'...  unknown  temporary
# 4  {'nativeName': 'English', 'code': 'en', 'name'...  unknown  temporary
#
#                  publishedAt  \
# 0  2014-07-30T11:12:00-05:00
# 1  2014-07-30T12:11:00-04:00
# 2  2014-07-30T08:50:00-07:00
# 3  2014-07-30T09:34:00-06:00
# 4  2014-07-30T08:34:00-07:00
#
#                                             remoteID       source  \
# 0  1406718720_466c6f6f64205761726e696e67206973737...  noaa_alerts
# 1  1406722260_5370656369616c205765617468657220537...  noaa_alerts
# 2  1406710200_52656420466c6167205761726e696e67206...  noaa_alerts
# 3  1406712840_486561742041647669736f7279206973737...  noaa_alerts
# 4  1406709240_486561742041647669736f7279206973737...  noaa_alerts
#
#                                              summary  \
# 0  Flood Warning issued July 30 at 11:12AM CDT un...
# 1  Special Weather Statement issued July 30 at 12...
# 2  Red Flag Warning issued July 30 at 8:50AM PDT ...
# 3  Heat Advisory issued July 30 at 9:34AM MDT unt...
# 4  Heat Advisory issued July 30 at 8:34AM PDT unt...
#
#                                                 tags  \
# 0  [{'confidence': 1, 'name': 'severe-weather'}, ...
# 1  [{'confidence': 1, 'name': 'severe-weather'}, ...
# 2  [{'confidence': 1, 'name': 'severe-weather'}, ...
# 3  [{'confidence': 1, 'name': 'severe-weather'}, ...
# 4  [{'confidence': 1, 'name': 'severe-weather'}, ...
#
#                     updatedAt
# 0  2014-07-30T16:27:11.639545
# 1  2014-07-30T16:27:12.532615
# 2  2014-07-30T16:27:12.710426
# 3  2014-07-30T16:27:12.022766
# 4  2014-07-30T16:27:13.077545

# %%
# View the first 10 data points
df.tail()
# Out:
#                                        author  \
# 339  {'remoteID': 'w-nws.webmaster@noaa.gov'}
# 340  {'remoteID': 'w-nws.webmaster@noaa.gov'}
# 341  {'remoteID': 'w-nws.webmaster@noaa.gov'}
# 342  {'remoteID': 'w-nws.webmaster@noaa.gov'}
# 343  {'remoteID': 'w-nws.webmaster@noaa.gov'}
#
#                                                content contentEnglish  \
# 339  .THE HIGH SURF ADVISORY HAS BEEN SUPERCEDED BY...            NaN
# 340  ...HEAT INDICES FROM 105 AND 109 DEGREES ARE E...            NaN
# 341  ...MODERATE RISK OF RIP CURRENTS CONTINUES TOD...            NaN
# 342  ...TORRENTIAL RAIN POSSIBLE FOR THE MARIANAS.....            NaN
# 343  ...VERY WARM WEATHER THIS WEEK IN SOUTHWEST WA...            NaN
#
#                       createdAt entities  \
# 339  2014-07-30T05:23:20.480002      NaN
# 340  2014-07-30T00:22:16.296060      NaN
# 341  2014-07-29T22:58:39.728048      NaN
# 342  2014-07-30T16:28:26.677591      NaN
# 343  2014-07-29T22:58:42.217762      NaN
#
#                                                fromURL  geo  \
# 339  http://alerts.weather.gov/cap/wwacapget.php?x=...  NaN
# 340  http://alerts.weather.gov/cap/wwacapget.php?x=...  NaN
# 341  http://alerts.weather.gov/cap/wwacapget.php?x=...  NaN
# 342  http://alerts.weather.gov/cap/wwacapget.php?x=...  NaN
# 343  http://alerts.weather.gov/cap/wwacapget.php?x=...  NaN
#
#                          id language  license   lifespan  \
# 339  DfYF7G7iTw6XtS4zDBKJtA      NaN  unknown  temporary
# 340  idFSIKhWSA6kFlbVvKA4KA      NaN  unknown  temporary
# 341  CxFRSKFtRpWstH3BZnhcSQ      NaN  unknown  temporary
# 342  X6QVM6_IQnKrqFEBYF546A      NaN  unknown  temporary
# 343  dGrk3ozKT2ecD2NnCPk96w      NaN  unknown  temporary
#
#                    publishedAt  \
# 339  2014-07-29T22:56:00+10:00
# 340  2014-07-29T04:36:00-05:00
# 341  2014-07-29T04:35:00-04:00
# 342  2014-07-29T10:03:00+10:00
# 343  2014-07-28T09:43:00-07:00
#
#                                               remoteID       source  \
# 339  1406674560_4869676820537572662041647669736f727...  noaa_alerts
# 340  1406608560_5370656369616c205765617468657220537...  noaa_alerts
# 341  1406608500_5269702043757272656e742053746174656...  noaa_alerts
# 342  1406628180_466c61736820466c6f6f642057617463682...  noaa_alerts
# 343  1406540580_5370656369616c205765617468657220537...  noaa_alerts
#
#                                                summary  \
# 339  High Surf Advisory issued July 29 at 10:56PM C...
# 340  Special Weather Statement issued July 29 at 4:...
# 341  Rip Current Statement issued July 29 at 4:35AM...
# 342  Flash Flood Watch issued July 29 at 10:03AM Ch...
# 343  Special Weather Statement issued July 28 at 9:...
#
#                                                   tags  \
# 339  [{'confidence': 1, 'name': 'severe-weather'}, ...
# 340  [{'confidence': 1, 'name': 'severe-weather'}, ...
# 341  [{'confidence': 1, 'name': 'severe-weather'}, ...
# 342  [{'confidence': 1, 'name': 'severe-weather'}, ...
# 343  [{'confidence': 1, 'name': 'severe-weather'}, ...
#
#                       updatedAt
# 339  2014-07-30T05:23:20.480012
# 340  2014-07-30T00:22:16.296070
# 341  2014-07-29T22:58:39.728061
# 342  2014-07-30T16:28:26.677605
# 343  2014-07-29T22:58:42.217773

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344 entries, 0 to 343
# Data columns (total 17 columns):
# author            344 non-null object
# content           344 non-null object
# contentEnglish    14 non-null object
# createdAt         344 non-null object
# entities          157 non-null object
# fromURL           344 non-null object
# geo               234 non-null object
# id                344 non-null object
# language          157 non-null object
# license           344 non-null object
# lifespan          344 non-null object
# publishedAt       344 non-null object
# remoteID          344 non-null object
# source            344 non-null object
# summary           344 non-null object
# tags              344 non-null object
# updatedAt         344 non-null object
# dtypes: object(17)

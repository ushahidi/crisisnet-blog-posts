# %% [markdown]
# # Scrape All Route Pages
#
# - By Chris Albon
# - September 9, 2014

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re
import numpy as np
import os

cur_dir = os.path.dirname(os.path.realpath('__file__'))

# %%
df_links = pd.read_csv(cur_dir + '/data/route_list.csv')

# %%
title = []
state = []
city = []
area = []
crag = []
wall = []
comments_name = []
comments_text = []
comments_loc = []
comments_date = []

# %%
for link in df_links['route_url']:
    
    r = requests.get(link)
    soup = BeautifulSoup(r.content)
    
    names = []
    text = []
    loc = []
    date = []
        
    try:
        title.append(soup.find('h1').text)
        
        breadcrumb = soup.findAll('span',{'itemprop':'title'})
        if len(breadcrumb) == 5:
            state.append(breadcrumb[0].text)
            city.append(breadcrumb[1].text)
            area.append(breadcrumb[2].text)
            crag.append(breadcrumb[3].text)
            wall.append(breadcrumb[4].text)
        elif len(breadcrumb) == 4:
            state.append(breadcrumb[0].text)
            city.append(breadcrumb[1].text)
            area.append(breadcrumb[2].text)
            crag.append(breadcrumb[3].text)
            wall.append(np.NaN)
        elif len(breadcrumb) == 3:
            state.append(breadcrumb[0].text)
            city.append(breadcrumb[1].text)
            area.append(breadcrumb[2].text)
            crag.append(np.NaN)
            wall.append(np.NaN)            
        elif len(breadcrumb) == 2:
            state.append(breadcrumb[0].text)
            city.append(breadcrumb[1].text)
            area.append(np.NaN)
            crag.append(np.NaN)
            wall.append(np.NaN)
        else:
            state.append(np.NaN)
            city.append(np.NaN)
            area.append(np.NaN)
            crag.append(np.NaN)
            wall.append(np.NaN)
        
        i = 0
        if len(soup.findAll('table', id=re.compile('^cm_'))) > 0:
            for comment in soup.findAll('table', id=re.compile('^cm_')):
                columns = comment.find_all('td')
                names.append(columns[0].find('a').text) 
                text.append(columns[1].text)
                if len(columns[0].findAll('br')) == 3:
                    loc.append(columns[0].find('br').nextSibling.text) 
                    date.append(columns[0].find('br').nextSibling.nextSibling.nextSibling.text) 
                    continue
                elif len(columns[0].findAll('br')) == 2:
                    loc.append(np.NaN)
                    date.append(columns[0].find('br').nextSibling.text)
                    continue
                i=i+1
                continue
        else:
            comments_name.append(np.NaN) 
            comments_text.append(np.NaN)
            comments_date.append(np.NaN) 
            comments_loc.append(np.NaN)
            i=i+1
            continue
            
        comments_name.append(str(names))
        comments_text.append(str(text))
        comments_date.append(str(date))
        comments_loc.append(str(loc)) 

    except:
        comments_name.append(str(names))
        comments_text.append(str(text))
        comments_date.append(str(date))
        comments_loc.append(str(loc)) 
        continue

# %%
df = pd.DataFrame()

df['title'] = title
df['url'] = df_links['route_url']
df['state'] = state
df['city'] = city
df['area'] = area
df['crag'] = crag
df['wall'] = wall
df['comments_name'] = comments_name
df['comments_text'] = comments_text
df['comments_date'] = comments_date
df['comments_loc'] = comments_loc

# %%
df.head()
# Out:
#                 title                                                url  \
# 0      Nobody's Fool   http://www.mountainproject.com/v/nobodys-fool/...
# 1       Black Groove   http://www.mountainproject.com/v/black-groove/...
# 2         Right Side   http://www.mountainproject.com/v/right-side/10...
# 3     Unknown Groove   http://www.mountainproject.com/v/unknown-groov...
# 4  I Looked at That!   http://www.mountainproject.com/v/i-looked-at-t...
#
#       state     city            area                               crag wall  \
# 0  Colorado  Boulder  Boulder Canyon               Above Tower of Babel  NaN
# 1  Colorado  Boulder  Boulder Canyon               Across From Cenotaph  NaN
# 2  Colorado  Boulder  Boulder Canyon               Across From Cenotaph  NaN
# 3  Colorado  Boulder  Boulder Canyon               Across From Cenotaph  NaN
# 4  Colorado  Boulder  Boulder Canyon  Across From Mind Shaft Cliff Crag  NaN
#
#   comments_name comments_text comments_date comments_loc
# 0           NaN           NaN           NaN          NaN
# 1           NaN           NaN           NaN          NaN
# 2           NaN           NaN           NaN          NaN
# 3           NaN           NaN           NaN          NaN
# 4           NaN           NaN           NaN          NaN

# %%
df.to_csv(cur_dir + '/data/route_data.csv_2', index=False)

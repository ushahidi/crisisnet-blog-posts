# %%
import requests
import pandas as pd

api_key = '532d8dc4ed3329652f114b73'
api_url = 'http://api.crisis.net/item/?sources=twitter'
headers = {'Authorization': 'Bearer ' + api_key}
total = 10000
df = pd.DataFrame()

def get_data(offset=0, limit=100, df=None):
  url = api_url + '&offset=' + str(offset) + '&limit=' + str(limit)
  r = requests.get(url, headers=headers)
  x = pd.DataFrame(r.json())
  x = x['data'].apply(pd.Series)
  df = df.append(x, ignore_index=True)

  if total > offset + limit:
    return get_data(offset + limit, limit, df)
    
  return df

df = get_data(df=df)

# %%
len(df)
# Out:
# 10000

# %%
df.head()
# Out:
#                                               author  \
# 0  {'name': 'Jeferson D'Addario', 'username': 'je...
# 1  {'name': 'Ingrid Brandão  ✌', 'username': 'Pre...
# 2  {'name': 'aline lobo', 'username': '_alinelobo...
# 3  {'name': 'ConflictReporter', 'username': 'Midd...
# 4  {'name': 'Ilham Kurniawan', 'username': 'IKSan...
#
#                                              content  \
# 0  O melhor protesto é na urna, e não destruindo ...
# 1  No meio dessa palhaçada de #VaiTerCopaSim X #N...
# 2  essa Copa me servia pra dar folgas, agora não ...
# 3  Argh, BS alarm all around...\nI condemn a kill...
# 4  RT @OccupyWorldCup: BAM! #FIFA \n\nExpect Us!!...
#
#                                       contentEnglish  \
# 0  The best protest is in the ballot box, and not...
# 1  Amid this farce of # X # VaiTerCopaSim NaoVaiT...
# 2  this Cup served to give me time off, not now b...
# 3                                                NaN
# 4                                                NaN
#
#                     createdAt                         entities  \
# 0  2014-06-17T14:45:33.823764  [Brazil, São José do Xingu, MT]
# 1  2014-06-17T14:45:32.731647  [Brazil, São José do Xingu, MT]
# 2  2014-06-17T14:45:32.772279  [Brazil, São José do Xingu, MT]
# 3  2014-06-17T14:45:31.209195               [General-conflict]
# 4  2014-06-17T14:45:32.807296  [Brazil, São José do Xingu, MT]
#
#                                                  geo                      id  \
# 0  {'addressComponents': {'adminArea1': 'Brazil',...  eu52J_TjTcKl2quhHmSppQ
# 1  {'addressComponents': {'adminArea1': 'Brazil',...  qqZHa2L5SKmDfRkvc_fiGg
# 2  {'addressComponents': {'adminArea1': 'Brazil',...  42B4O4LUSKyBq9MPuUnMHQ
# 3  {'addressComponents': {'adminArea1': 'General-...  TvekZYT2RLi_qGRu8NdwAQ
# 4  {'addressComponents': {'adminArea1': 'Brazil',...  HXKdGQ1FR7KRinUtLfJFsg
#
#                                             image        language  license  \
# 0                                             NaN  {'code': 'pt'}  twitter
# 1                                             NaN  {'code': 'pt'}  twitter
# 2                                             NaN  {'code': 'pt'}  twitter
# 3                                             NaN  {'code': 'en'}  twitter
# 4  http://pbs.twimg.com/media/BqSuMSECUAAHuW5.jpg  {'code': 'en'}  twitter
#
#     lifespan                publishedAt            remoteID   source  \
# 0  temporary  2014-06-17T14:46:13+00:00  478911496257544193  twitter
# 1  temporary  2014-06-17T14:46:07+00:00  478911472513613824  twitter
# 2  temporary  2014-06-17T14:46:03+00:00  478911456197746688  twitter
# 3  temporary  2014-06-17T14:46:01+00:00  478911446076882944  twitter
# 4  temporary  2014-06-17T14:45:57+00:00  478911430582738944  twitter
#
#                                              summary  \
# 0  O melhor protesto é na urna, e não destruindo ...
# 1  No meio dessa palhaçada de #VaiTerCopaSim X #N...
# 2  essa Copa me servia pra dar folgas, agora não ...
# 3  Argh, BS alarm all around...\nI condemn a kill...
# 4  RT @OccupyWorldCup: BAM! #FIFA \n\nExpect Us!!...
#
#                                                 tags  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'name': 'armed-conflict', 'confidence': 1}, ...
# 4                                                 []
#
#                     updatedAt
# 0  2014-06-17T14:49:09.758214
# 1  2014-06-17T14:47:57.514872
# 2  2014-06-17T14:48:05.346361
# 3  2014-06-17T14:46:39.280817
# 4  2014-06-17T14:48:06.645723
#
# [5 rows x 17 columns]

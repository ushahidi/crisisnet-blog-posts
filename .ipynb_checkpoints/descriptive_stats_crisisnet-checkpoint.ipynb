# %% [markdown]
# # Getting Descriptive Statistics
#
# CrisisNET provides a simple, powerful resource for accessing crisis relevant data. Below is a short introduction to pulling down data from CrisisNET and completing some simple data wrangling tasks — setting you up to start pulling and using data on your own.
#
# The example below uses Python 3.3 and was written in iPython notebook. The notebook is avaliable on Nbviewer.

# %% [markdown]
# ### Import required modules

# %%
import requests as re
from mpl_toolkits.basemap import Basemap
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Set pandas to display a maximum of 30 columns

# %%
pd.set_option('display.max_columns', 30)

# %% [markdown]
# ### Create and make an api request to CrisisNET

# %%
api_key = '532d8dc4ed3329652f114b73'
headers = {'Authorization': 'Bearer ' + api_key}
url = 'http://devapi.crisis.net/item?limit=200'
r = re.get(url, headers=headers)
request_df = pd.DataFrame(r.json())

# %% [markdown]
# ### Clean up the dataframe

# %%
# Create a dataframe from the request's data
df = request_df['data'].apply(pd.Series)

# Set the row index of the dataframe to be the time the report was updated
df["updatedAt"] = pd.to_datetime(df["updatedAt"])
df.index = df['updatedAt']

# Expand the geo column into a full dataframe
geo_df = df['geo'].apply(pd.Series)

# Expand the address components column into it's own dataframe
geo_admin_df = geo_df['addressComponents'].apply(pd.Series)

# Join the two geo dataframes to the primary dataframe
df = pd.concat([df[:], geo_admin_df[:], geo_df[:]], axis=1)

# Extract the latitute and longitude coordinates into their own columns
df['latitude'] = df['coords'].str[1]
df['longitude'] = df['coords'].str[0]

# Expand the tags column into its own dataframe
tags_df = df['tags'].apply(pd.Series)

# Drop everything column after the second column
tags_df = tags_df.ix[:, 0:1]
tags_df.columns = ['tag1', 'tag2']

# Extract the tags
def tag_extractor(x):
    # that, if x is a string,
    if type(x) is float:
        # just returns it untouched
        return x
    # but, if not, convert x to a dict() and return the value from the name key
    elif x:
        x = dict(x)
        return x['name']
    # and leave everything else
    else:
        return
tags_df = tags_df.applymap(tag_extractor)

# Attach the tags to the main dataframe
df = pd.concat([df[:], tags_df[:]], axis=1)

# Expand the language value:key pair
lang_df = df['language'].apply(pd.Series)

# Attach the language code as a column
df['lang'] = lang_df['code']

# print the length and view the first row
print(len(df))
df.head(1)
# Out:
# 200
#                            author  \
# updatedAt
# 2014-06-01 04:20:26.650610    NaN
#
#                                                                   content  \
# updatedAt
# 2014-06-01 04:20:26.650610  Mohammed Yehya al-Houndi killed by Shooting.
#
#                                              createdAt  \
# updatedAt
# 2014-06-01 04:20:26.650610  2014-06-01T04:20:26.650600
#
#                                                                       fromURL  \
# updatedAt
# 2014-06-01 04:20:26.650610  http://www.vdc-sy.info/index.php/en/details/ma...
#
#                                                                           geo  \
# updatedAt
# 2014-06-01 04:20:26.650610  {'addressComponents': {'neighborhood': 'Sanama...
#
#                                                 id image language  license  \
# updatedAt
# 2014-06-01 04:20:26.650610  JY3h2j-_RWaGSoBdD6Ey0w   NaN      NaN  unknown
#
#                              lifespan          publishedAt remoteID  \
# updatedAt
# 2014-06-01 04:20:26.650610  temporary  2014-09-16T00:00:00   111181
#
#                                source  \
# updatedAt
# 2014-06-01 04:20:26.650610  vdc_syria
#
#                                                              summary  \
# updatedAt
# 2014-06-01 04:20:26.650610  Adult - Male Civilian killed by Shooting
#
#                                                                          tags  \
# updatedAt
# 2014-06-01 04:20:26.650610  [{'confidence': 1, 'name': 'conflict'}, {'conf...
#
#                                             updatedAt video adminArea1  \
# updatedAt
# 2014-06-01 04:20:26.650610 2014-06-01 04:20:26.650610   NaN      Syria
#
#                            adminArea3 neighborhood  \
# updatedAt
# 2014-06-01 04:20:26.650610      Daraa     Sanamain
#
#                                                             addressComponents  \
# updatedAt
# 2014-06-01 04:20:26.650610  {'neighborhood': 'Sanamain', 'adminArea1': 'Sy...
#
#                            coords locationIdentifiers  latitude  longitude  \
# updatedAt
# 2014-06-01 04:20:26.650610    NaN                 NaN       NaN        NaN
#
#                                 tag1   tag2 lang
# updatedAt
# 2014-06-01 04:20:26.650610  conflict  death  NaN
#
# [1 rows x 28 columns]

# %% [markdown]
# ### Number of observations per source

# %%
df['source'].value_counts().fillna(0).plot(kind='bar')

# %% [markdown]
# ### Number of observations per language

# %%
df['lang'].value_counts().fillna(0).plot(kind='bar')

# %% [markdown]
# ### Number of observations per country

# %%
df['adminArea1'].value_counts().fillna(0).plot(kind='bar')

# %% [markdown]
# ### View number of times a tag is appears

# %%
tags = pd.DataFrame([df['tag1'], df['tag2']])
tag_counts = tags.stack().value_counts()
tag_counts
# Out:
# conflict    4
# death       4
# dtype: int64

# %% [markdown]
# ### Plot number of times a tag is appears

# %%
tags.stack().value_counts().plot(kind='bar')

# %% [markdown]
# ### View the source of observation by source

# %%
pd.crosstab(df['adminArea1'], df['source'], rownames=['SOURCE:'], colnames=['LOCATION:'])
# Out:
# LOCATION:  facebook  facebook_syria  instagram  twitter  vdc_syria
# SOURCE:
# Syria            84              25          0        1          4
# Thailand          3               0          4       79          0
#
# [2 rows x 5 columns]

# %% [markdown]
# ### View the language of observations by location

# %%
pd.crosstab(df['adminArea1'], df['lang'], rownames=['LOCATION:'], colnames=['LANGUAGE:'])
# Out:
# LANGUAGE:  en  in  th
# LOCATION:
# Syria       1   0   0
# Thailand    8   1  70
#
# [2 rows x 3 columns]

# %% [markdown]
# ### View the header and footer of the dataframe

# %%
df.head()
# Out:
#                                                                        author  \
# updatedAt
# 2014-06-01 04:20:26.650610                                                NaN
# 2014-06-01 04:20:27.475816                                                NaN
# 2014-06-01 04:20:28.032481                                                NaN
# 2014-06-01 04:20:28.662130                                                NaN
# 2014-06-02 03:08:36.420750  {'username': 'poomipatto', 'remoteID': '105787...
#
#                                                                       content  \
# updatedAt
# 2014-06-01 04:20:26.650610      Mohammed Yehya al-Houndi killed by Shooting.
# 2014-06-01 04:20:27.475816  Al Jearo killed by Shelling. Did not reach ful...
# 2014-06-01 04:20:28.032481  Matrah killed by Other. Did not reach full nam...
# 2014-06-01 04:20:28.662130  Al Darweish killed by Warplane shelling. Did n...
# 2014-06-02 03:08:36.420750                Paradoxocracy 🙈🙉🙊 #Thaicoup #nocoup
#
#                                              createdAt  \
# updatedAt
# 2014-06-01 04:20:26.650610  2014-06-01T04:20:26.650600
# 2014-06-01 04:20:27.475816  2014-06-01T04:20:27.475805
# 2014-06-01 04:20:28.032481  2014-06-01T04:20:28.032470
# 2014-06-01 04:20:28.662130  2014-06-01T04:20:28.662119
# 2014-06-02 03:08:36.420750  2014-06-02T03:08:36.420724
#                                                                          tags  \
# updatedAt
# 2014-06-01 04:20:26.650610  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 2014-06-01 04:20:27.475816  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 2014-06-01 04:20:28.032481  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 2014-06-01 04:20:28.662130  [{'confidence': 1, 'name': 'conflict'}, {'conf...
# 2014-06-02 03:08:36.420750                                                NaN
#
#                                             updatedAt video adminArea1  \
# updatedAt
# 2014-06-01 04:20:26.650610 2014-06-01 04:20:26.650610   NaN      Syria
# 2014-06-01 04:20:27.475816 2014-06-01 04:20:27.475816   NaN      Syria
# 2014-06-01 04:20:28.032481 2014-06-01 04:20:28.032481   NaN      Syria
# 2014-06-01 04:20:28.662130 2014-06-01 04:20:28.662130   NaN      Syria
# 2014-06-02 03:08:36.420750 2014-06-02 03:08:36.420750   NaN   Thailand
#
#                            adminArea3             neighborhood  \
# updatedAt
# 2014-06-01 04:20:26.650610      Daraa                 Sanamain
# 2014-06-01 04:20:27.475816      Idlib  Jisr Shagour: Ganaudieh
# 2014-06-01 04:20:28.032481      Idlib                 Telminis
# 2014-06-01 04:20:28.662130      Idlib                 Telminis
# 2014-06-02 03:08:36.420750        NaN                      NaN
#
#                                                             addressComponents  \
# updatedAt
# 2014-06-01 04:20:26.650610  {'neighborhood': 'Sanamain', 'adminArea1': 'Sy...
# 2014-06-01 04:20:27.475816  {'neighborhood': 'Jisr Shagour: Ganaudieh', 'a...
# 2014-06-01 04:20:28.032481  {'neighborhood': 'Telminis', 'adminArea1': 'Sy...
# 2014-06-01 04:20:28.662130  {'neighborhood': 'Telminis', 'adminArea1': 'Sy...
# 2014-06-02 03:08:36.420750                         {'adminArea1': 'Thailand'}
#
#                                           coords locationIdentifiers  \
# updatedAt
# 2014-06-01 04:20:26.650610                   NaN                 NaN
# 2014-06-01 04:20:27.475816                   NaN                 NaN
# 2014-06-01 04:20:28.032481                   NaN                 NaN
# 2014-06-01 04:20:28.662130                   NaN                 NaN
# 2014-06-02 03:08:36.420750  [98.67907, 18.42295]                 NaN
#
#                             latitude  longitude      tag1   tag2 lang
# updatedAt
# 2014-06-01 04:20:26.650610       NaN        NaN  conflict  death  NaN
# 2014-06-01 04:20:27.475816       NaN        NaN  conflict  death  NaN
# 2014-06-01 04:20:28.032481       NaN        NaN  conflict  death  NaN
# 2014-06-01 04:20:28.662130       NaN        NaN  conflict  death  NaN
# 2014-06-02 03:08:36.420750  18.42295   98.67907       NaN    NaN  NaN
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#                                                                        author  \
# updatedAt
# 2014-06-02 01:41:39.653853  {'username': 'WassanaNanuam', 'remoteID': '267...
# 2014-06-02 01:53:10.443875                                                NaN
# 2014-06-02 02:53:33.169114                                                NaN
# 2014-06-02 01:53:10.551497                                                NaN
# 2014-06-02 02:53:33.327977                                                NaN
#
#                                                                       content  \
# updatedAt
# 2014-06-02 01:41:39.653853  กองทัพเรือเผยเรืออรพิน4 กลับมาถึงศรีราชา4ทุ่มเ...
# 2014-06-02 01:53:10.443875  CH8: لقاء مع مجموعة من ابطا�... http://t.co/0U...
# updatedAt
# 2014-06-02 01:41:39.653853               473274992595968000         twitter
# 2014-06-02 01:53:10.443875  260678550763320_306534916177683  facebook_syria
# 2014-06-02 02:53:33.169114  260678550763320_306534916177683        facebook
# 2014-06-02 01:53:10.551497  260678550763320_306534912844350  facebook_syria
# 2014-06-02 02:53:33.327977  260678550763320_306534912844350        facebook
#
#                                                                       summary  \
# updatedAt
# 2014-06-02 01:41:39.653853                                                NaN
# 2014-06-02 01:53:10.443875                                                NaN
# 2014-06-02 02:53:33.169114  CH8: لقاء مع مجموعة من ابطا�... http://t.co/0U...
# 2014-06-02 01:53:10.551497                                                NaN
# 2014-06-02 02:53:33.327977  CH8: منال أكرم البريدي اب�... http://t.co/Vm3m...
#
#                            tags                  updatedAt video adminArea1  \
# updatedAt
# 2014-06-02 01:41:39.653853  NaN 2014-06-02 01:41:39.653853   NaN   Thailand
# 2014-06-02 01:53:10.443875  NaN 2014-06-02 01:53:10.443875   NaN      Syria
# 2014-06-02 02:53:33.169114  NaN 2014-06-02 02:53:33.169114   NaN      Syria
# 2014-06-02 01:53:10.551497  NaN 2014-06-02 01:53:10.551497   NaN      Syria
# 2014-06-02 02:53:33.327977  NaN 2014-06-02 02:53:33.327977   NaN      Syria
#
#                            adminArea3 neighborhood  \
# updatedAt
# 2014-06-02 01:41:39.653853        NaN          NaN
# 2014-06-02 01:53:10.443875        NaN          NaN
# 2014-06-02 02:53:33.169114        NaN          NaN
# 2014-06-02 01:53:10.551497        NaN          NaN
# 2014-06-02 02:53:33.327977        NaN          NaN
#
#                                      addressComponents coords  \
# updatedAt
# 2014-06-02 01:41:39.653853  {'adminArea1': 'Thailand'}    NaN
# 2014-06-02 01:53:10.443875     {'adminArea1': 'Syria'}    NaN
# 2014-06-02 02:53:33.169114     {'adminArea1': 'Syria'}    NaN
# 2014-06-02 01:53:10.551497     {'adminArea1': 'Syria'}    NaN
# 2014-06-02 02:53:33.327977     {'adminArea1': 'Syria'}    NaN
#
#                                                           locationIdentifiers  \
# updatedAt
# 2014-06-02 01:41:39.653853  {'authorTimeZone': None, 'authorLocationName':...
# 2014-06-02 01:53:10.443875                                                NaN
# 2014-06-02 02:53:33.169114                                                NaN
# 2014-06-02 01:53:10.551497                                                NaN
# 2014-06-02 02:53:33.327977                                                NaN
#
#                             latitude  longitude tag1 tag2 lang
# updatedAt
# 2014-06-02 01:41:39.653853       NaN        NaN  NaN  NaN   th
# 2014-06-02 01:53:10.443875       NaN        NaN  NaN  NaN  NaN
# 2014-06-02 02:53:33.169114       NaN        NaN  NaN  NaN  NaN
# 2014-06-02 01:53:10.551497       NaN        NaN  NaN  NaN  NaN
# 2014-06-02 02:53:33.327977       NaN        NaN  NaN  NaN  NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Plot the dates of the observations

# %%
df['createdAt'] = pd.to_datetime(df['createdAt'])
d2 = df.set_index('createdAt').resample('D', 'count')
d2.drop_duplicates(take_last=False, inplace=True)
d2 = d2.unstack().rename(columns={'content': 'daily_total'})
d2 = d2['daily_total']
d2.plot(kind='bar')

# %% [markdown]
# ### View number of missing observations per variable

# %%
df.apply(lambda x: x.isnull().value_counts()).T.plot(kind='bar', stacked=True)

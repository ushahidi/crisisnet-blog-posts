# %%
# Import modules
import pandas as pd
import requests

# %%
api_key = '532d8dc4ed3329652f114b73'
api_url = 'http://api.crisis.net/item/?sources=ushahidi&limit=100'
headers = {'Authorization': 'Bearer ' + api_key}
offset = 0
df = pd.DataFrame()

# %%
for x in range(0, 10):
    url = api_url + '&offset=' + str(offset + 100)
    r = requests.get(url, headers=headers)
    x = pd.DataFrame(r.json())
    x = x['data'].apply(pd.Series)
    df = df.append(x)
    offset = offset + 10

# %%
total = 1000

def get_and_write(offset=0,limit=100):
    url = 'http://api.crisis.net/item?placeName=nigeria'
    headers = {'Authorization': 'Bearer 532d32c7ed3329652f114b70'}
    r = requests.get(url, headers=headers)
    json_resp = r.json()

    docs = json_resp['data']
    total = json_resp['total']

    with open(cur_dir + '/articles.txt', 'a') as f:
        for doc in docs:
            f.write(doc['id'] + "\n")

    new_offset = offset + limit
    if total > new_offset:
        get_and_write(offset=new_offset)

# %%
len(df)
# Out:
# 1000

# %%
df
# Out:
#                                               content  \
# 0   "Of all the household chores I hate, I probabl...
# 1   NepalMonitor.org SMS Alert:Biratnagar, Balatka...
# 2   NepalMonitor.org SMS Alert:Morang,youn shausan...
# 3   NepalMonitor.org SMS Alert:Saptari,Balatkaarka...
# 4   Tragedy struck Lagos Friday as a petrol tanker...
# 5   NepalMonitor.org SMS Alert:Chautara,Ghar ma ba...
# 6   My dog is sooo awesome! She makes my day bette...
# 7   YAY for people who return things they find on ...
# 8   A causa de las bajas temperaturas del fin de s...
# 9   Buongiorno\napprofitto del vostro utilissimo b...
# 10  This dots for advice given, taken, or ignored-...
# 11                Mangrove sapling about 2 feet tall.
# 12  Large mangrove tree growing near water.  Lots ...
# 13  Drumul nu este reparat timp de peste 2 ani. As...
# 14  Mr. Ndidiamaka Nwagba of Camp Peace hotel, Sab...
# 15  When we acquired the site three years ago, the...
# ...

# %% [markdown]
# ##

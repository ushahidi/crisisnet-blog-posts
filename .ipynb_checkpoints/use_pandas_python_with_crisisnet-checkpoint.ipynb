# %% [markdown]
# # Use Python and pandas with CrisisNET

# %%
# import required modules
import requests as re
import pandas as pd

# %%
# Set pandas to display a maximum of 30 columns
pd.set_option('display.max_columns', 30)

# %%
# Create a variable with your CrisisNET API key
api_key = '532d8dc4ed3329652f114b73'

# Setup the request header
headers = {'Authorization': 'Bearer ' + api_key}

# %%
# Setup the request's URL
url = 'http://devapi.crisis.net/item?%(tags)s&%(before)s&%(after)s&%(text)s&%(location)s&%(radius)s&%(limit)s&%(sources)s&%(licenses)s&%(offset)s'

# Create a list of filters
filters =   {'tags' : 'tags=', # a list of keywords seperated by comma
             'after' : 'after=', # a timestamp in ISO 8601 format
             'before' : 'before=', # a timestamp in ISO 8601 format
             'text' : 'text=', # words seperated by a '+'
             'location' : 'location=', # latitude and longitude
             'radius' : 'radius=', # a number in meters
             'limit' : 'limit=', # the maximum number of records to return
             'sources' : 'sources=reliefweb', # a list of sources
             'licenses' : 'licenses=', # the types of licenses
             'offset' : 'offset=' # for multiple requests
            }

# Create the formatted request URL
formattedURL = url % filters

# %%
# Request data from CrisisNET
r = re.get(formattedURL, headers=headers)

# Check to make sure the pull was successful
# If successful, we will see "Response 200"
print(r)
# Out:
# <Response [200]>

# %%
# Create a dataframe from the request's json format
request_df = pd.DataFrame(r.json())

# %%
# View the first five rows of the request dataframe
request_df.head(1)
# Out:
#                                                 data  total
# 0  {'language': {'code': 'en'}, 'id': 'AcVAF46mQC...    458
#
# [1 rows x 2 columns]

# %%
# Create a dataframe from the request's data
df = request_df['data'].apply(pd.Series)

# %%
# View the first five rows of the dataframe
df.head(1)
# Out:
#                                              content  \
# 0  As at 31 Mar 2014, 11 provinces (nine in north...
#
#                     createdAt                           entities  \
# 0  2014-05-09T19:07:06.931101  [Afghanistan, Badakhshan, Faryab]
#
#                                                  geo                      id  \
# 0  {'coords': [72, 36.75], 'addressComponents': {...  AcVAF46mQC6X_qpvC2SQpA
#
#          language  license   lifespan               publishedAt remoteID  \
# 0  {'code': 'en'}  unknown  temporary  2014-04-25T00:00:00.000Z    14539
#
#       source                                            summary  \
# 0  reliefweb  Afghanistan: Flash Floods and Landslides - Apr...
#
#                                                 tags  \
# 0  [{'confidence': 1, 'name': 'flood'}, {'confide...
#
#                     updatedAt
# 0  2014-05-11T16:12:32.345574
#
# [1 rows x 14 columns]

# %%
# Check the length of the dataframe
len(df)
# Out:
# 25

# %%
# Set the row index of the dataframe to be the time the report was updated
df["updatedAt"] = pd.to_datetime(df["updatedAt"])
df.index = df['updatedAt']

# %%
# Expand the geo column into a full dataframe
geo_df = df['geo'].apply(pd.Series)
geo_df.head(100)
# Out:
#                                                             addressComponents  \
# updatedAt
# 2014-05-11 16:12:32.345574  {'formattedAddress': 'Afghanistan', 'adminArea...
# 2014-05-11 16:12:07.193385  {'adminArea5': 'Ulytauskiy rayon', 'formattedA...
# 2014-05-11 17:24:46.603082  {'adminArea5': 'Paiwas', 'formattedAddress': '...
# 2014-05-11 17:23:44.444621  {'formattedAddress': '3580000 Linares, Maule, ...
# 2014-05-11 17:24:30.183069  {'formattedAddress': '75 S Broadway Ave, Peru,...
# 2014-05-11 17:24:27.212385  {'formattedAddress': 'Ruta Langahua Central, P...
# 2014-05-11 17:24:09.095631  {'formattedAddress': 'Sierra Leone', 'adminAre...
# 2014-05-11 17:24:36.606412  {'formattedAddress': 'Guinea', 'adminArea1': '...
# 2014-05-11 17:24:21.817394  [-52.788028717041016, -10.81116008758545]
#
# [25 rows x 2 columns]

# %%
# Expand the address components column into it's own dataframe
geo_admin_df = geo_df['addressComponents'].apply(pd.Series)
geo_admin_df.head(1)
# Out:
#                              adminArea1 adminArea3 adminArea4 adminArea5  \
# updatedAt
# 2014-05-11 16:12:32.345574  Afghanistan        NaN        NaN        NaN
#
#                            formattedAddress postalCode streetAddress
# updatedAt
# 2014-05-11 16:12:32.345574      Afghanistan        NaN           NaN
#
# [1 rows x 7 columns]

# %%
# Join the two geo dataframes to the primary dataframe
df = pd.concat([df[:], geo_admin_df[:], geo_df[:]], axis=1)

# %%
# Extract the latitute and longitude coordinates into their own columns
df['latitude'] = df['coords'].str[1]
df['longitude'] = df['coords'].str[0]

# %%
# Expand the tags column into its own dataframe
tags_df = df['tags'].apply(pd.Series)

# %%
# Drop everything column after the fourth
tags_df = tags_df.ix[:, 0:1]

# %%
# Add titles to the columns
tags_df.columns = ['tag1', 'tag2']
tags_df.columns
# Out:
# Index(['tag1', 'tag2'], dtype='object')

# %%
# View the first few rows of the tags dataframe
tags_df.head(1)
# Out:
#                                                           tag1  \
# updatedAt
# 2014-05-11 16:12:32.345574  {'confidence': 1, 'name': 'flood'}
#
#                                                                 tag2
# updatedAt
# 2014-05-11 16:12:32.345574  {'confidence': 1, 'name': 'flash-flood'}
#
# [1 rows x 2 columns]

# %%
# Create a tag extractor function that leaves missing observations (which are floats) alone, but converts other values into dicts, then extracts the name value.

# Create a function called tag_extractor,
def tag_extractor(x):
    # that, if x is a string,
    if type(x) is float:
        # just returns it untouched
        return x
    # but, if not,
    elif x:
        # converts x to a dict(),
        x = dict(x)
        # and returns the value from the name key
        return x['name']
    # and leaves everything else
    else:
        return

# %%
# Apply the function to every cell in the dataframe
tags_df = tags_df.applymap(tag_extractor)

# %%
# Join the tags dataframe with the primary dataframe
df = pd.concat([df[:], tags_df[:]], axis=1)

# %%
# Expand the language column into it's own dataframe and return the language code column to the original dataframe
lang_df = df['language'].apply(pd.Series)
df['lang'] = lang_df['code']

# %%
# Drop some extra columns to clean up the dataframe
df = df.drop(['geo', 'updatedAt', 'addressComponents', 'language', 'tags', 'coords', 'id', 'remoteID', ], axis=1)

# %%
# View the final dataframe
df.head()
# Out:
#                                                                       content  \
# updatedAt
# 2014-05-11 16:12:32.345574  As at 31 Mar 2014, 11 provinces (nine in north...
# 2014-05-11 16:12:07.193385  A flash flood triggered by a dam burst on 31 M...
# 2014-05-11 17:24:46.603082  On 10 Apr 2014, a shallow 6.2-magnitude earthq...
# 2014-05-11 17:23:44.444621  On 1 Apr 2014, a 8.2-magnitude earthquake occu...
# 2014-05-11 17:24:30.183069  On 1 Apr 2014, a 8.2-magnitude earthquake occu...
#
#                                              createdAt  \
# updatedAt
# 2014-05-11 16:12:32.345574  2014-05-09T19:07:06.931101
# 2014-05-11 16:12:07.193385  2014-05-09T17:08:52.744816
# 2014-05-11 17:24:46.603082  2014-04-29T22:34:14.876123
# 2014-05-11 17:23:44.444621  2014-04-29T22:34:09.003365
# 2014-05-11 17:24:30.183069  2014-04-29T22:34:18.449345
#
#                                                                      entities  \
# updatedAt
# 2014-05-11 16:12:32.345574                  [Afghanistan, Badakhshan, Faryab]
# 2014-05-11 16:12:07.193385  [Kokpekty, Kazakhstan, Ulytauskiy rayon, Qarag...

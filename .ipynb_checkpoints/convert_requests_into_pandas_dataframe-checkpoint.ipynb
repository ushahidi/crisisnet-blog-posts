# %% [markdown]
# # Convert a CrisisNET Requests into a pandas dataframe

# %% [markdown]
# ## Preliminaries

# %%
# Import the required modules
import requests as re
import pandas as pd

# Set iPython's max column width to 50
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## Make the CrisisNET API requests

# %%
# Create a variable with your CrisisNET API key
api_key = '532d8dc4ed3329652f114b73'

# Setup the request header
headers = {'Authorization': 'Bearer ' + api_key}

# Setup the request's URL
url = 'http://api.crisis.net/item?limit=200&sources=facebook'

# Make the API request
r = re.get(url, headers=headers)

# %% [markdown]
# ## Create the JSON to dataframe function

# %%
# Define a function that,
def request_to_df(r):
    # converts the json into a dataframe,
    request_df = pd.DataFrame(r.json())
    # expands the df.data cell,
    df = request_df['data'].apply(pd.Series)
    # converts df.updatedAt to a datetime object,
    df["updatedAt"] = pd.to_datetime(df["updatedAt"])
    # sets it as the dataframe's index,
    df.index = df['updatedAt']
    # expands the df.geo object,
    geo_df = df['geo'].apply(pd.Series)
    # expands the admin zones,
    geo_admin_df = geo_df['addressComponents'].apply(pd.Series)
    # merges the admin zones back into the dataframe,
    df = pd.concat([df[:], geo_admin_df[:], geo_df[:]], axis=1)
    # seperates the lat and long objects,
    df['latitude'], df['longitude'] = df['coords'].str[1], df['coords'].str[0]
    # expands df.tags,
    tags_df = df['tags'].apply(pd.Series)
    # defines a function called tag_extractor,
    def tag_extractor(x):
        # that, if x is a string,
        if type(x) is float:
            # just returns it untouched
            return x
        # but, if not, convert x to a dict() and return the value
        elif x:
            x = dict(x)
            return x['name']
        # and leave everything else
        else:
            return
    # executes tag_extractor on the tags dataframe,
    tags_df = tags_df.applymap(tag_extractor)
    # renames all the tag columns,
    tags_df = tags_df.rename(columns = lambda x : 'tag_' + str(x))
    # merges everything back together,
    df = pd.concat([df[:], tags_df[:]], axis=1)
    # expands df.language,
    lang_df = df['language'].apply(pd.Series)
    # takes the language code,
    df['lang'] = lang_df['code']
    # and finally returns the primary dataframe
    return df

# %% [markdown]
# ## Execute the function on the API request

# %%
# Create a dataframe, df, which is the output 
# of running request_to_df() on the request, r
df = request_to_df(r)

# %% [markdown]
# ## View the dataframe

# %%
# View the first three rows of the dataframe
df.head(3)
# Out:
#                                                                       content  \
# updatedAt
# 2014-06-13 01:46:38.494363  #شبكات_أخبار_سوريا_المتحدة\n\nبدء حرب الخليج ا...
# 2014-06-13 01:44:52.074039  #ملخص أخبار و فيديوهات إدلب الخميس 12-6-2014\n...
# 2014-06-13 01:44:54.822377  حُزنْ آلشآمْ مُبكِي .. وَ جُرحْ آلعِرآق قآتِل ...
#
#                                                                contentEnglish  \
# updatedAt
# 2014-06-13 01:46:38.494363  News networks _ # _ Syria _ the United\n\nThe ...
# 2014-06-13 01:44:52.074039  # Summary of News and Videos Idlib Thursday 06...
# 2014-06-13 01:44:54.822377  Sham Mbeki grief .. and wounded Iraq killer .....
#
#                                              createdAt entities  \
# updatedAt
# 2014-06-13 01:46:38.494363  2014-06-13T01:46:22.125857  [Syria]
# 2014-06-13 01:44:52.074039  2014-06-13T01:40:35.307502  [Syria]
# 2014-06-13 01:44:54.822377  2014-06-13T01:41:34.040705  [Syria]
#
#                                                                       fromURL  \
# updatedAt
# 2014-06-13 01:46:38.494363  http://facebook.com/213849965318722_6794085120...
# 2014-06-13 01:44:52.074039                http://facebook.com/594563310642260
# 2014-06-13 01:44:54.822377  http://facebook.com/135492153291427_2980575137...
#
#                                                                           geo  \
# updatedAt
# 2014-06-13 01:46:38.494363  {'addressComponents': {'formattedAddress': 'Sy...
# 2014-06-13 01:44:52.074039  {'locationIdentifiers': {'authorLocationName':...
# 2014-06-13 01:44:54.822377  {'addressComponents': {'formattedAddress': 'Sy...
#
#                                                 id  \
# updatedAt
# 2014-06-13 01:46:38.494363  3-6X_ObNRLm43MmdBb8m2Q
# 2014-06-13 01:44:52.074039  4Eoa7Zu9QdiBMRcToO-RiQ
# 2014-06-13 01:44:54.822377  lZrDabrhTIqY0p_LPwmCbQ
#
#                                                                         image  \
# updatedAt
# 2014-06-13 01:46:38.494363                                                NaN
# 2014-06-13 01:44:52.074039  https://scontent-a.xx.fbcdn.net/hphotos-xfa1/t...
# 2014-06-13 01:44:54.822377                                                NaN
#
#                                                                      language  \
# updatedAt
# 2014-06-13 01:46:38.494363  {'nativeName': 'العربية', 'code': 'ar', 'name'...
# 2014-06-13 01:44:52.074039  {'nativeName': 'العربية', 'code': 'ar', 'name'...
# 2014-06-13 01:44:54.822377  {'nativeName': 'اردو', 'code': 'ur', 'name': '...
#
#                              license   lifespan                publishedAt  \
# updatedAt
# 2014-06-13 01:46:38.494363  facebook  temporary  2014-06-13T01:45:01+00:00
# 2014-06-13 01:44:52.074039  facebook  temporary  2014-06-13T01:32:19+00:00
# 2014-06-13 01:44:54.822377  facebook  temporary  2014-06-13T01:31:27+00:00
#
#                                                    remoteID    source  \
# updatedAt
# 2014-06-13 01:46:38.494363  213849965318722_679408512096196  facebook
# 2014-06-13 01:44:52.074039                  594563310642260  facebook
# 2014-06-13 01:44:54.822377  135492153291427_298057513701556  facebook
#
#                                                                       summary  \
# updatedAt
# 2014-06-13 01:46:38.494363  #شبكات_أخبار_سوريا_المتحدة\n\nبدء حرب الخليج ا...
# 2014-06-13 01:44:52.074039  #ملخص أخبار و فيديوهات إدلب الخميس 12-6-2014\n...
# 2014-06-13 01:44:54.822377  حُزنْ آلشآمْ مُبكِي .. وَ جُرحْ آلعِرآق قآتِل ...
#
#                                                                          tags  \
# updatedAt
# 2014-06-13 01:46:38.494363            [{'confidence': 1, 'name': 'military'}]
# 2014-06-13 01:44:52.074039  [{'confidence': 1, 'name': 'armed-conflict'}, ...
# 2014-06-13 01:44:54.822377  [{'confidence': 1, 'name': 'armed-conflict'}, ...
#
#                                             updatedAt video adminArea1  \
# updatedAt
# 2014-06-13 01:46:38.494363 2014-06-13 01:46:38.494363   NaN      Syria
# 2014-06-13 01:44:52.074039 2014-06-13 01:44:52.074039   NaN      Syria
# 2014-06-13 01:44:54.822377 2014-06-13 01:44:54.822377   NaN      Syria
#
#                            formattedAddress  \
# updatedAt
# 2014-06-13 01:46:38.494363            Syria
# 2014-06-13 01:44:52.074039            Syria
# 2014-06-13 01:44:54.822377            Syria
#
#                                                             addressComponents  \
# updatedAt
# 2014-06-13 01:46:38.494363  {'formattedAddress': 'Syria', 'adminArea1': 'S...
# 2014-06-13 01:44:52.074039  {'formattedAddress': 'Syria', 'adminArea1': 'S...
# 2014-06-13 01:44:54.822377  {'formattedAddress': 'Syria', 'adminArea1': 'S...
#
#                                                              coords  \
# updatedAt
# 2014-06-13 01:46:38.494363  [38.473472595214844, 35.03312683105469]
# 2014-06-13 01:44:52.074039  [38.473472595214844, 35.03312683105469]
# 2014-06-13 01:44:54.822377  [38.473472595214844, 35.03312683105469]
#
#                                                          locationIdentifiers  \
# updatedAt
# 2014-06-13 01:46:38.494363                                               NaN
# 2014-06-13 01:44:52.074039  {'authorLocationName': 'Idlib Jisr Al-Shughour'}
# 2014-06-13 01:44:54.822377                                               NaN
#
#                              latitude  longitude           tag_0     tag_1  \
# updatedAt
# 2014-06-13 01:46:38.494363  35.033127  38.473473        military       NaN
# 2014-06-13 01:44:52.074039  35.033127  38.473473  armed-conflict  conflict
# 2014-06-13 01:44:54.822377  35.033127  38.473473  armed-conflict  conflict
#
#                             tag_2   tag_3 lang
# updatedAt
# 2014-06-13 01:46:38.494363    NaN     NaN   ar
# 2014-06-13 01:44:52.074039  death  rebels   ar
# 2014-06-13 01:44:54.822377  death     NaN   ur
#
# [3 rows x 30 columns]

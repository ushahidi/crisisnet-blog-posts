# %% [markdown]
# # Exploring CrisisNET's Sources API

# %% [markdown]
# ### Import required modules

# %%
import requests
import pandas as pd

# Set the max number of row and columns displayed,
# as well as the number of characters displayed in each cell
pd.set_option('display.max_row', 1000)
pd.set_option('display.max_column', 50)
pd.set_option('max_colwidth', 500)

# %% [markdown]
# ### Make an API Request

# %%
url = 'http://api.crisis.net/source'
headers = {'Authorization': 'Bearer ' + '532d8dc4ed3329652f114b73'}

r = requests.get(url, headers=headers)

# %% [markdown]
# ### Convert the request's JSON into a dataframe

# %%
df = pd.DataFrame(r.json())
df = df['data'].apply(pd.Series)
df_sources = pd.concat([df['uniqueName'], df['sourceType'], df['description'], df['lastRun'], df['startDate'], df['repeatsEvery'], df['status']], axis=1 )

# %% [markdown]
# ### View active sources and relevent info

# %%
df_sources[df_sources['status'] == 'active']
# Out:
#             uniqueName  sourceType  \
# 0                  NaN    ushahidi
# 1                  NaN   reliefweb
# 3                  NaN     twitter
# 5            who_ebola         who
# 6        syria_tracker    ushahidi
# 7           test_sucka  test_sucka
# 8       facebook_syria    facebook
# 9        youtube_syria     youtube
# 11        instagrammer   instagram
# 12               unhcr       unhcr
# 13  facebook_terrorism    facebook
# 14     unocha_iraq_idp      unocha
# 15           osm_ebola         osm
# 16           vdc_syria   vdc_syria
# 17                noaa        noaa
# 18                ptwc        noaa
# 19             twitter     twitter
# 20           noaa_news        noaa
# 21         noaa_alerts        noaa
# 22                 pdc         pdc
# 23                nwcg        nwcg
# 24         ushahidi_v2    ushahidi
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                     description  \
# 0                                                                                                                                                                                                                                                                                                                         Aggregated incident reports from all publicly accessible   Ushahidi instances, both self-hosted and Crowdmap Classic.
# 1                                                                                                                                                                                                                                                                                                                                                                   Historical and recent natural disaster reports from ReliefWeb's public API.
# 3                                                                                                                                                                                                                                                                                                                                                                                                         Traffic incidents in or near Nairobi.
# 5                                                                                                                                                                                                                                                                                                                                                                                                              WHO Ebola virus disease reports
# 6                                                                                                                                                                                                                                                                                                                                                                                    SyriaTracker Ushahidi instance. syriatracker.crowdmap.com
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                           NaN
# 8                                                                                                                                                                                                                                                                                                                                 About 1k Facebook pages relevant to ongoing conflict in Syria, \ncourtesy of Eliot Higgins (aka Brown Moses)
# 9                                                                                                                                                                                                                                                                                                                               About 1k YouTube channels relevant to ongoing conflict in Syria, \ncourtesy of Eliot Higgins (aka Brown Moses)
# 11                                                                                                                                                                                                                                                                                                                                                                                           Requests to photos tagged to places in Instagram.
# 12   The Office of the United Nations High Commissioner for Refugees (UNHCR), also known as the UN Refugee Agency, is a United Nations agency mandated to protect and support refugees at the request of a government or the UN itself and assists in their voluntary repatriation, local integration or resettlement to a third country. Its headquarters are in Geneva, Switzerland and is a member of the United Nations Development Group.
# 13                                                                                                                                                                                                                                                                                                                                          Facebook pages of terrorist organizations or journalists/agencies/etc tracking those organizations
# 14                                                                                                                                                                                                                                                                                                                                                                                               Iraq New IDPs summary by Province from UNOCHA
# 15                                                                                                                                                                                                                                                                                                                                                                             Open Street Map layers focused on Ebola outbreak in west Africa
# 16                                                                                                                                                                          Violation Documentation Center in Syria is an independent, \n    civil non-profit, non-governmental organization that started its work of \n    monitoring and documenting the violations of human rights in Syria since \n    April 2011. http://www.vdc-sy.info/
# 17                                                                                                                                                                                                                                                      The National Oceanic and Atmospheric Administration is a scientific agency within the United States Department of Commerce focused on the conditions of the oceans and the atmosphere.
# 18                                                                                                        NOAA's two Tsunami Warning Centers (PTWC and WC/ATWC) have separate areas of responsibility, which are the geographical areas within which each Center has the responsibility for the dissemination of messages and the provision of interpretive information to emergency managers and other officials, news media, and the public.
# 19                                                                                                                                                                                                                                                                                                                                                                        First-person accounts from regions affected by conflict and diaster.
# 20                                                                                                                                                                                                                                                                                                                                                  Latest Weather News Headlines for the United States Issued by the National Weather Service
# 21                                                                                                                                                                                                                                                                                                                                       Current Watches, Warnings and Advisories for the United States Issued by the National Weather Service
# 22                                                                                                                                                                                                                                                  Pacific Disaster Center uses information, science, and technology to enable effective evidence-based decision making and to promote disaster risk reduction (DRR) concepts and strategies.
# 23                                                                                                                                                                                                                                                                                                                              NWCG is an operational group designed to coordinate programs of the participating wildfire management agencies
# 24                                                                                                                                                                                                                                                                                                                                                                             Public instances of the Ushahidi crowdsourced mapping platform.
#
#                      lastRun                 startDate repeatsEvery  status
# 0   2014-05-04T04:41:28.375Z  2014-03-30T00:00:00.000Z         hour  active
# 1   2014-05-12T22:56:51.993Z  2014-03-30T00:00:00.000Z          day  active
# 3                        NaN  2014-03-19T00:00:00.000Z       minute  active
# 5   2014-08-05T22:30:52.835Z  2014-05-07T00:00:00.000Z          day  active
# 6   2014-05-11T18:19:51.962Z  2014-05-07T00:00:00.000Z         hour  active
# 7                        NaN  2014-08-05T05:01:42.127Z         hour  active
# 8   2014-08-06T02:57:52.677Z  2014-05-07T00:00:00.000Z         hour  active
# 9   2014-08-06T02:59:26.303Z  2014-05-07T00:00:00.000Z         hour  active
# 11  2014-08-06T03:00:02.055Z  2014-05-07T00:00:00.000Z         hour  active
# 12  2014-08-05T12:45:36.482Z  2014-05-07T00:00:00.000Z          day  active
# 13  2014-08-06T02:42:20.753Z  2014-05-07T00:00:00.000Z         hour  active
# 14  2014-08-05T13:51:12.571Z  2014-05-07T00:00:00.000Z          day  active
# 15  2014-08-06T01:19:46.197Z  2014-05-07T00:00:00.000Z          day  active
# 16                       NaN  2014-05-07T00:00:00.000Z          day  active
# 17  2014-07-30T16:28:07.862Z  2014-05-07T00:00:00.000Z         hour  active
# 18                       NaN  2014-05-07T00:00:00.000Z         hour  active
# 19  2014-08-06T02:44:21.448Z  2014-05-07T00:00:00.000Z         hour  active
# 20  2014-07-30T16:28:25.165Z  2014-05-07T00:00:00.000Z         hour  active
# 21  2014-08-02T00:24:48.721Z  2014-05-07T00:00:00.000Z         hour  active
# 22  2014-07-31T19:09:39.292Z  2014-05-07T00:00:00.000Z         hour  active
# 23  2014-08-01T18:56:14.934Z  2014-05-07T00:00:00.000Z         hour  active
# 24  2014-08-05T04:12:27.247Z  2014-05-07T00:00:00.000Z          day  active
